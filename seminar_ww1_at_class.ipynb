# %% [markdown]
# <a href="https://colab.research.google.com/github/alinaalborova/nlp_course/blob/master/seminar_ww1_at_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seminar 1

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# --2020-01-20 06:16:53--  https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.1, 2620:100:6032:1::a27d:5201
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/obaitrix9jyu84r/quora.txt [following]
# --2020-01-20 06:16:53--  https://www.dropbox.com/s/dl/obaitrix9jyu84r/quora.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com/cd/0/get/AwhS-jZTFbI2WzfaZZrafCc7KOBji_7W2hQJEiKDUhpauxBB5PBvUexAsjKonGOLe0Jfwop_Gu32jdGXAeXME182CkjOOCEkKLiYTtcTOrCprw/file?dl=1# [following]
# --2020-01-20 06:16:54--  https://ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com/cd/0/get/AwhS-jZTFbI2WzfaZZrafCc7KOBji_7W2hQJEiKDUhpauxBB5PBvUexAsjKonGOLe0Jfwop_Gu32jdGXAeXME182CkjOOCEkKLiYTtcTOrCprw/file?dl=1
# Resolving ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com (ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com)... 162.125.82.6, 2620:100:6032:6::a27d:5206
# Connecting to ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com (ucc87e0446e23a58b93ca072adaa.dl.dropboxusercontent.com)|162.125.82.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33813903 (32M) [application/binary]
# Saving to: ‘./quora.txt’
#
# ./quora.txt         100%[===================>]  32.25M  7.03MB/s    in 4.6s
#
# 2020-01-20 06:16:59 (7.01 MB/s) - ‘./quora.txt’ saved [33813903/33813903]

# %%
import numpy as np

data = list(open("./quora.txt", encoding="utf-8"))
data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
# TASK: lowercase everything and extract tokens with tokenizer. 
# data_tok should be a list of lists of tokens for each line in data.

data_tok = []
for line in data:
  line_lower = []
  for token in line:
    line_lower.append(token.lower())
  data_tok.append(tokenizer.tokenize(''.join(line_lower)))
print(data_tok[50])
# Out:
# ['what', 'tv', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
assert all(isinstance(row, (list, tuple)) for row in data_tok), "please convert each line into a list of tokens (strings)"
assert all(all(isinstance(tok, str) for tok in row) for row in data_tok), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all('a' <= x.lower() <= 'z' for x in tok)
assert all(map(lambda l: not is_latin(l) or l.islower(), map(' '.join, data_tok))), "please make sure to lowercase the data"

# %%
print([' '.join(row) for row in data_tok[:2]])
# Out:
# ["can i get back with my ex even though she is pregnant with another guy ' s baby ?", 'what are some ways to overcome a fast food addiction ?']

# %%
from gensim.models import Word2Vec
model = Word2Vec(data_tok, 
                 size=32,      # embedding vector size
                 min_count=5,  # consider words that occured at least 5 times
                 window=5).wv  # define context as a 5-word window around the target word

# %%
# now you can get word vectors !
model.get_vector('anything')
# Out:
# array([-4.2331505 , -1.1681336 , -1.0872872 ,  0.9758311 , -1.4791626 ,
#        -0.2711192 , -0.87110883,  1.6921341 , -0.4949173 ,  2.7307417 ,
#         0.20360947, -0.81710047,  3.930585  , -0.48108172,  1.9766607 ,
#         4.069594  ,  0.8449277 ,  3.7096012 ,  2.9389684 ,  1.1658254 ,
#         0.8705773 ,  0.09933327, -0.39930573,  0.9991129 , -0.3830553 ,
#         1.6717438 , -1.092133  ,  1.7474937 ,  2.1264882 , -2.788471  ,
#        -4.148889  ,  1.0382569 ], dtype=float32)

# %%
# or query similar words directly. Go play with it!
model.most_similar('bread')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('rice', 0.9528794288635254),
#  ('sauce', 0.9332154989242554),
#  ('butter', 0.9316112995147705),
#  ('cheese', 0.9232503175735474),
#  ('beans', 0.9152141809463501),
#  ('fruit', 0.9117721319198608),
#  ('soup', 0.9079678058624268),
#  ('banana', 0.9029287099838257),
#  ('chicken', 0.9028729796409607),
#  ('flour', 0.9019712805747986)]

# %% [markdown]
# ## Pretrained Model

# %%
import gensim.downloader as api
model = api.load('glove-twitter-100')
# Out:
# [=============================================-----] 91.3% 353.6/387.1MB downloaded

# %%
model.most_similar(positive=["coder", "money"], negative=["brain"])
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('broker', 0.5820155739784241),
#  ('bonuses', 0.5424473285675049),
#  ('banker', 0.538511335849762),
#  ('designer', 0.5197198390960693),
#  ('merchandising', 0.4964233934879303),
#  ('treet', 0.49220192432403564),
#  ('shopper', 0.4920561909675598),
#  ('part-time', 0.49128279089927673),
#  ('freelance', 0.4843311905860901),
#  ('aupair', 0.4796452522277832)]

# %% [markdown]
# ## Visualize Word Vectors

# %%
words = sorted(model.vocab.keys(), 
               key=lambda word: model.vocab[word].count,
               reverse=True)[:1000]

print(words[::100])
# Out:
# ['<user>', '_', 'please', 'apa', 'justin', 'text', 'hari', 'playing', 'once', 'sei']

# %%
# for each word, compute its vector with model
word_vectors = []
for word in words:
  word_vectors.append(model.get_vector(word))
word_vectors = np.asarray(word_vectors)
print(word_vectors[:2])
# Out:
# [[ 0.63006    0.65177    0.25545    0.018593   0.043094   0.047194
#    0.23218    0.11613    0.17371    0.40487    0.022524  -0.076731
#   -2.2911     0.094127   0.43293    0.041801   0.063175  -0.64486
#   -0.43657    0.024114  -0.082989   0.21686   -0.13462   -0.22336
#    0.39436   -2.1724    -0.39544    0.16536    0.39438   -0.35182
#   -0.14996    0.10502   -0.45937    0.27729    0.8924    -0.042313
#   -0.009345   0.55017    0.095521   0.070504  -1.1781     0.013723
#    0.17742    0.74142    0.17716    0.038468  -0.31684    0.08941
#    0.20557   -0.34328   -0.64303   -0.878     -0.16293   -0.055925
#    0.33898    0.60664   -0.2774     0.33626    0.21603   -0.11051
#    0.0058673 -0.64757   -0.068222  -0.77414    0.13911   -0.15851
#   -0.61885   -0.10192   -0.47       0.19787    0.42175   -0.18458
#    0.080581  -0.22545   -0.065129  -0.15328    0.087726  -0.18817
#   -0.08371    0.21779    0.97899    0.1092     0.022705  -0.078234
#    0.15595    0.083105  -0.6824     0.57469   -0.19942    0.50566
#   -0.18277    0.37721   -0.12514   -0.42821   -0.81075   -0.39326
#   -0.17386    0.55096    0.64706   -0.6093   ]
#  [ 0.18205   -0.048483   0.23966    0.32099   -0.27002    0.70431
#   -0.21257    0.235      0.090142   0.82141    0.37843   -0.56382
#   -2.4447     0.16827    0.24685    0.28649    0.062312   0.067508
#   -0.58459   -0.45414   -0.22158    0.17423   -0.35558    0.14485
#    0.49089   -1.7426    -0.54306   -0.51937    0.94795   -0.41739
#   -0.55238   -0.057398  -0.52663    0.62976    0.097275   0.20637
#    0.46261    0.089462   0.016019  -0.53854   -1.2043     0.080287
#   -0.65351    0.044617   0.79527    0.044508   0.53367    0.27444
#   -0.32461   -0.053683  -0.79304    0.11       0.39762   -0.044155
#    0.21701    0.27977   -0.25773    0.25085    0.39711    0.32318
#    0.10245   -0.030471   0.34113    0.17971    0.44436    0.054915
#    0.22461   -0.80843   -0.11052    0.42366    0.61091    0.55024
#    0.21958   -0.3029     0.14545   -0.46701   -0.23945    0.035106
#   -0.50933   -0.12392    0.24526    0.14758   -0.30313   -0.53052
#    0.80632    0.34566   -0.24541    0.71479   -0.15985    0.40129
#   -0.10851   -0.61427   -0.0035577  0.037739  -0.33055   -0.094383
#    0.38617   -0.3358     0.18884   -0.40786  ]]

# %%
assert isinstance(word_vectors, np.ndarray)
assert word_vectors.shape == (len(words), 100)
assert np.isfinite(word_vectors).all()

# %% [markdown]
# ### Linear Projection: Principal Component Analysis (PCA)
#
# The simplest linear dimensionality reduction method is Principial Component Analysis.
#
# In geometric terms, PCA tries to find axes along which most of the variance occurs.
#
# ![](https://camo.githubusercontent.com/a68740188733509d867957a6b37712fa6253d2fd/68747470733a2f2f6769746875622e636f6d2f79616e646578646174617363686f6f6c2f50726163746963616c5f524c2f7261772f6d61737465722f7965745f616e6f746865725f7765656b2f5f7265736f757263652f7063615f666973682e706e67)
#
# Under the hood, it attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing mean squared error:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# $X \in \mathbb{R}^{n \times m}$ - object matrix (centered);
# $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# $n$ samples, $m$ original dimensions and $d$ target dimensions

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
# map word vectors onto 2d plane with PCA. Use good old sklearn api (fit, transform)
# after that, normalize vectors to make sure they have zero mean and unit variance
pca = PCA(n_components=2)
word_vectors_pca = pca.fit_transform(word_vectors)
print(word_vectors_pca)
word_vectors_pca = StandardScaler().fit_transform(word_vectors_pca)
print(word_vectors_pca)
#word_vectors_pca = pd.DataFrame(data = principal_components, columns = ['principal component 1', 'principal component 2'])
#word_vectors_pca = # YOUR CODE

# and maybe MORE OF YOUR CODE here :)
# Out:
# [[ 0.9333838   0.5037093 ]
#  [ 0.7293041   0.36441985]
#  [ 1.1819206   0.6137326 ]
#  ...
#  [ 2.5400124  -2.3040001 ]
#  [-0.07835463  0.48636183]
#  [-2.0053227  -0.22080526]]
# [[ 0.38816702  0.29139513]
#  [ 0.30329648  0.21081646]
#  [ 0.49152592  0.35504332]
#  ...
#  [ 1.056315   -1.3328586 ]
#  [-0.0325842   0.28135964]
#  [-0.8339516  -0.12773497]]

# %%
assert word_vectors_pca.shape == (len(word_vectors), 2), "there must be a 2d vector for each word"
assert max(abs(word_vectors_pca.mean(0))) < 1e-5, "points must be zero-centered"
assert max(abs(1.0 - word_vectors_pca.std(0))) < 1e-2, "points must have unit variance"

# %% [markdown]
# ### Visualization of Clusters

# %%
import bokeh.models as bm, bokeh.plotting as pl
from bokeh.io import output_notebook
output_notebook()

def draw_vectors(x, y, radius=10, alpha=0.25, color='blue',
                 width=600, height=400, show=True, **kwargs):
    """ draws an interactive plot for data points with auxilirary info on hover """
    if isinstance(color, str): color = [color] * len(x)
    data_source = bm.ColumnDataSource({ 'x' : x, 'y' : y, 'color': color, **kwargs })

    fig = pl.figure(active_scroll='wheel_zoom', width=width, height=height)
    fig.scatter('x', 'y', size=radius, color='color', alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show: pl.show(fig)
    return fig

# %%
draw_vectors(word_vectors_pca[:, 0], word_vectors_pca[:, 1], token=words)

# hover a mouse over there and see if you can identify the clusters
# Out:
#   <div class="bk-root" id="4ab20ec5-ca98-49e4-b837-e0b457efbfd8" data-root-id="1002"></div>
# Figure(id='1002', ...)

# %% [markdown]
# ## Visualizing Neighbors with t-SNE
#
# PCA is nice but it's strictly linear and thus only able to capture coarse high-level structure of the data.
#
# If we instead want to focus on keeping neighboring points near, we could use [TSNE](https://distill.pub/2016/misread-tsne/), which is itself an embedding method.

# %%
from sklearn.manifold import TSNE

# map word vectors onto 2d plane with TSNE. hint: use verbose=100 to see what it's doing.
# normalize them as just lke with pca

tsne = TSNE(n_components=2, verbose=100)
word_tsne = tsne.fit_transform(word_vectors)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.008s...
# [t-SNE] Computed neighbors for 1000 samples in 0.244s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 1.716133
# [t-SNE] Computed conditional probabilities in 0.060s
# [t-SNE] Iteration 50: error = 68.5191956, gradient norm = 0.3164679 (50 iterations in 15.620s)
# [t-SNE] Iteration 100: error = 68.5511627, gradient norm = 0.2962393 (50 iterations in 14.631s)
# [t-SNE] Iteration 150: error = 68.4254074, gradient norm = 0.3029585 (50 iterations in 14.996s)
# [t-SNE] Iteration 200: error = 68.9571838, gradient norm = 0.2944084 (50 iterations in 204.648s)
# [t-SNE] Iteration 250: error = 68.8135452, gradient norm = 0.2903307 (50 iterations in 353.453s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.813545

# %%
word_tsne = StandardScaler().fit_transform(word_tsne)

# %%
draw_vectors(word_tsne[:, 0], word_tsne[:, 1], color='green', token=words)

# %% [markdown]
# ## Visualize Phrases

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def get_phrase_embedding(phrase):
    """
    Convert phrase to a vector by aggregating it's word embeddings. See description above.
    """
    # 1. lowercase phrase
    phrase_lower = phrase.lower()
    # 2. tokenize phrase
    tokens = nltk.word_tokenize(phrase)
    # 3. average word vectors for all words in tokenized phrase
    # skip words that are not in model's vocabulary
    # if all words are missing from vocabulary, return zeros
    token_vectors = []
    for token in tokens:
      try: 
        token_vectors.append(model.get_vector(token))
      except:
        token_vectors.append(np.zeros([model.vector_size], dtype='float32'))
    avg_vector = np.mean(token_vectors, axis=0)
    return avg_vector


    # YOUR CODE
    
    #return vector
        
#get_phrase_embedding('What a day!')
get_phrase_embedding("I'm very sure. This never happened to me before...")[::10]
# Out:
# array([ 0.26728266, -0.05069667,  0.16060583, -0.00243728, -0.667494  ,
#        -0.15167634,  0.17277159,  0.06088366,  0.9743908 , -0.00277224],
#       dtype=float32)

# %%
vector = get_phrase_embedding("I'm very sure. This never happened to me before...")

assert np.allclose(vector[::10],
                   np.array([ 0.31807372, -0.02558171,  0.0933293 , -0.1002182 , -1.0278689 ,
                             -0.16621883,  0.05083408,  0.17989802,  1.3701859 ,  0.08655966],
                              dtype=np.float32))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-00c1fbf57af0> in <module>()
#       4                    np.array([ 0.31807372, -0.02558171,  0.0933293 , -0.1002182 , -1.0278689 ,
#       5                              -0.16621883,  0.05083408,  0.17989802,  1.3701859 ,  0.08655966],
# ----> 6                               dtype=np.float32))
#
# AssertionError:

# %%
# let's only consider ~5k phrases for a first run.
chosen_phrases = data[::len(data) // 1000]

# compute vectors for chosen phrases
phrase_vectors = [get_phrase_embedding(x) for x in chosen_phrases]

# %%
assert isinstance(phrase_vectors, np.ndarray) and np.isfinite(phrase_vectors).all()
assert phrase_vectors.shape == (len(chosen_phrases), model.vector_size)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-7b16145b9b94> in <module>()
# ----> 1 assert isinstance(phrase_vectors, np.ndarray) and np.isfinite(phrase_vectors).all()
#       2 assert phrase_vectors.shape == (len(chosen_phrases), model.vector_size)
#
# AssertionError:

# %%
# map vectors into 2d space with pca, tsne or your other method of choice
# don't forget to normalize

phrase_vectors_2d = StandardScaler().fit_transform(phrase_vectors)

phrase_vectors_2d = (phrase_vectors_2d - phrase_vectors_2d.mean(axis=0)) / phrase_vectors_2d.std(axis=0)

# %%
draw_vectors(phrase_vectors_2d[:, 0], phrase_vectors_2d[:, 1],
             phrase=[phrase[:50] for phrase in chosen_phrases],
             radius=20,)
# Out:
#   <div class="bk-root" id="5795443e-4066-49d2-a9ed-ef3a446e4ba4" data-root-id="1109"></div>
# Figure(id='1109', ...)

# %%
# compute vector embedding for all lines in data
data_vectors = np.array([get_phrase_embedding(l) for l in data])

# %%
from scipy.spatial.distance import cosine

# %%
def find_nearest(query, k=10):
    """
    given text line (query), return k most similar lines from data, sorted from most to least similar
    similarity should be measured as cosine between query and line embedding vectors
    hint: it's okay to use global variables: data and data_vectors. see also: np.argpartition, np.argsort
    """
    query_vec = get_phrase_embedding(query)
    distances = [cosine(query_vec, i) for i in data_vectors]
    distances = np.argpartition(distances, k)
    results = [data[i] for i in distances]
    return results

# %%
results = find_nearest(query="How do i enter the matrix?", k=10)

print(''.join(results))

assert len(results) == 10 and isinstance(results[0], str)
assert results[0] == 'How do I get to the dark web?\n'
assert results[3] == 'What can I do to save the world?\n'
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-d2a8992e72e8> in <module>()
#       3 print(''.join(results))
#       4
# ----> 5 assert len(results) == 10 and isinstance(results[0], str)
#       6 assert results[0] == 'How do I get to the dark web?\n'
#       7 assert results[3] == 'What can I do to save the world?\n'
#
# AssertionError:

# %%
find_nearest(query="How does Trump?", k=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# ['What does Inefficiency?\n',
#  'Why does Net Neutrality Matters?\n',
#  'Why does 2*2^-2=0.5?\n',
#  'How does Enterprise Mobile Solution Benefit Businesses?\n',
#  'How does Unity 3D Work?\n',
#  'What does CANA PROFILE IN TECHMAHINDRA?\n',
#  'What does VMV?\n',
#  'Why does 3+3=6?\n',
#  'Why does pyschopath triangulate?\n',
#  'How does America WIN?\n',
#  'How does Augmented Reality Work?\n',
#  'Why does 2+3=5 not 6?\n',
#  'How does Magnus Carlsen think?\n',
#  'Why does Hillary Clinton like Saul Alinsky?\n',
#  'Why does Justin Bieber like Selena Gomez?\n',
#  'Why does Jake Williams like Nick?\n',
#  'What does Windows 8.1 Single Language mean?\n',
#  'Who does Ash Ketchum like?\n',
#  'What does 5 ATM Water Resistant mean?\n',
#  'What does Jimmy Wales think?\n',
#  'How does Richard Feynman think?\n',
#  'What does Puella Magi Madoka Magica mean?\n',
#  'What does 自分を愛する mean?\n',
#  'What does RAP mean?\n',
#  'What does OVA mean?\n',
#  'What does Bash mean?\n',
#  'What does NBA mean?\n',
#  'What does |-/ mean?\n',
#  'What does Product Market Fit mean?\n',
#  'What does NDR mean?\n',
#  'What does 好萌阿 mean?\n',
#  'What does 逆転の法則 mean?\n',
#  'What does 亮瞎了 mean?\n',
#  'What does 爱不释手 mean?\n',
#  'What does Natasha mean?\n',
#  'What does OMS mean?\n',
#  'What does 礼义廉耻 mean?\n',
#  'What does ICK mean?\n',
#  'What does ╥_╥ mean?\n',
#  'What does SENSEX mean?\n',
#  'What does flimpist mean?\n',
#  'What does 3.3e-5 mean?\n',
#  'What does GG mean?\n',
#  'What does Lakh mean?\n',
#  'What does psomí mean?\n',
#  'What does sociolinguistics mean?\n',
#  'What does w5w mean?\n',
#  'What does sex-positive mean?\n',
#  'What does caricatured mean?\n',
#  'What does Accenture mean?\n',
#  'What does Salary Grade 3s mean?\n',
#  'What does 有緣無份 mean?\n',
#  'What does 逆天 mean?\n',
#  'What does YOLO mean?\n',
#  'What does mean AU?\n',
#  'What does FWB mean?\n',
#  'What does Win32 mean?\n',
#  'What does BFF mean?\n',
#  'What does subgi mean?\n',
#  'What does धर्मकोटी mean?\n',
#  'What does mahummed mean?\n',
#  'What does NC-17 mean?\n',
#  'What does API mean?\n',
#  'What does 啪啪啪啪 mean?\n',
#  'What does Pradhan Mantri Jan Dhan Yojana mean?\n',
#  'What does unrooted mean?\n',
#  'What does mAh mean?\n',
#  'What does OBO mean?\n',
#  'What does Etymology mean?\n',
#  'What does Autonomous Sensory Meridian mean?\n',
#  'What does XFN mean?\n',
#  'What does 任せてほしい mean?\n',
#  'What does A.D. mean?\n',
#  'What does RLWL77/WL77 mean?\n',
#  'What does +x+ mean?\n',
#  'What does SMH mean?\n',
#  'What does 슬마 mean?\n',
#  'What does D.C. mean?\n',
#  'What does WTF mean?\n',
#  'What does 小幸运 mean?\n',
#  'What does 1.1i mean?\n',
#  'What does 我有一个二货朋友 mean?\n',
#  'What does TGIF mean?\n',
#  'What does AAing mean?\n',
#  'What does Mayday Mayday Mayday mean?\n',
#  'What does HTTP Error 503 Service Unavailable mean?\n',
#  'What does Tumblr mean?\n',
#  'What does 枯萎 mean?\n',
#  'What is polymerization? What uses does it have?\n',
#  'When does Master Theorem fail?\n',
#  'What does 嘚瑟 mean?\n',
#  'In motion-capture, what does re-targeting mean?\n',
#  'In Naruto, what does Konoha mean?\n',
#  'What does Mammoth IIRC mean?\n',
#  'What does tw4t mean?\n',
#  'What does 时尚达人 mean?\n',
#  'Why does Quora have downvotes?\n',
#  'What does Mood Indigo mean?\n',
#  'What does Slim Shady mean?\n',
#  'What does 吴刚伐桂 mean?\n',
#  'What does April 19 mean?\n',
#  'What does SAE 80 mean?\n',
#  'What does 抜け感 mean?\n',
#  'How does Pakistan see Shivaji Maharaj?\n',
#  'How does Matt Murdock see?\n',
#  'What does ΙΧΣ mean?\n',
#  'What does Google mean?\n',
#  'What does BBN Planet mean?\n',
#  'Why does shanfa chaiyada look Caucasian?\n',
#  'What does Alma Mater mean?\n',
#  'What is FPGA? How does that works?\n',
#  'What does Gurren Lagann mean?\n',
#  'What does Googling mean?\n',
#  'What does chronicity mean?\n',
#  'What does Sagittarius mean?\n',
#  'What does Lorem Ipsum mean?\n',
#  'Should I learn SQL or NoSQL? MySQL or MongoDB? And why?\n',
#  'How does UPS Next Day Air works?\n',
#  'What does Cortana mean?\n',
#  'How does ICEfaces works?\n',
#  'What does ICS mean?\n',
#  'What does EEUU mean?\n',
#  'What does Wall Street mean?\n',
#  'Why does India need Swachh Bharat Abhiyan?\n',
#  'What is InCallUI? How does it work?\n',
#  'What does Hare Krishna mean?\n',
#  'What does E mean?\n',
#  'What does RAW mean?\n',
#  'What does Shuster Hall means?\n',
#  'What does ἐμβαίνομεν mean?\n',
#  'Do mermaids/mermans exist? Why or why not?\n',
#  'What does brexit mean?\n',
#  'Which is better CWM or TWRP? And why?\n',
#  'What does ACL debridement mean?\n',
#  'What does 심하잖아 mean?\n',
#  'What does Snapchat mean?\n',
#  'What does Stay Woke mean?\n',
#  'What does SSL mean?\n',
#  'What does Ghani Bawri means?\n',
#  'How does GST works?\n',
#  'Are ribosomes organelles? Why or why not?\n',
#  'What does Shuster Hall mean?\n',
#  'What is DNS? How does it work?\n',
#  'How does pixals.com works?\n',
#  'How does CashnoCash.com works?\n',
#  'What does MSG do? Why is it bad?\n',
#  'What does magizhchi mean?\n',
#  'How does .9*.9=.81 when 9*9=81?\n',
#  'What does IMO mean?\n',
#  'Why does Sino- mean Chinese?\n',
#  'What does Uruguay mean?\n',
#  'What CRM does Marriott use?\n',
#  'What does E.T.A. mean?\n',
#  'How does Snapchat works?\n',
#  'How does one Predict Time-series Data Using C++?\n',
#  'How does PPF works?\n',
#  'What does IC 741 mean?\n',
#  'What does ℝ² mean?\n',
#  'What does No Temperature mean?\n',
#  'What does 802.11b/g/n/AC mean?\n',
#  'How does CB Antenna works?\n',
#  'What does WYSIWYG mean?\n',
#  'What is STOCK MARKET? How does it work?\n',
#  'What CMS does modelmayhem.com use?\n',
#  'What does ABC mean?\n',
#  'What does Revelation 21:8 mean?\n',
#  'What does IBIDA mean?\n',
#  'What does さあひる mean?\n',
#  'What does Cinema Paradiso mean?\n',
#  'What does 100mAh means?\n',
#  'What does LA Devotee mean?\n',
#  'What is illuminati? What does it do?\n',
#  'How does Musical.ly make Money?\n',
#  'What does 니콜라스에게 mean?\n',
#  'How does PDF works?\n',
#  'How does Adobe Creative Cloud works?\n',
#  'What does mean AUSM?\n',
#  'How does GPS works?\n',
#  'What does Ola mean?\n',
#  'What does scapulae mean?\n',
#  'On American TV what does 6a/5c mean?\n',
#  'What does GMOとくとくポイント mean?\n',
#  'What does hh4u mean?\n',
#  'Who is Satan? What does the Bible say?\n',
#  'What does Bank PO mean?\n',
#  'What does F2F mean?\n',
#  'What does 玩坏 mean?\n',
#  'What does IC mean?\n',
#  'What does Revelation 21:1 mean?\n',
#  'What does εἶμεν mean?\n',
#  'What does qingding mean?\n',
#  'What does FIITJEE RSM have?\n',
#  'What does FOB Shanghai mean?\n',
#  'Why does Node.js need V8?\n',
#  'What does Quora mean?\n',
#  'How does Instagram use Django?\n',
#  'Should South Indians learn Hindi? Why or why not?\n',
#  'How does Amazon use Deep Learning?\n',
#  'How does Viagra work?\n',
#  'What CMS does Hillaryclinton.com use?\n',
#  'How does Siri work?\n',
#  'How does Windows Server 2012 work?\n',
#  'How does OAuth 2.0 work?\n',
#  'How does Meerkat work?\n',
#  'How does watchcount.com work?\n',
#  'How does Uber work?\n',
#  'How does Neuro-Linguistic Programming work?\n',
#  'How does Blackcore Edge Max work?\n',
#  'How does Paytm work?\n',
#  'How does Indian Railway work?\n',
#  'How does blippy.com work?\n',
#  'How does SHAREit work?\n',
#  'Why does Pakistan want Kashmir?\n',
#  'How does Feedspot work?\n',
#  'Why does San Marino exist?\n',
#  'How does Amazon Remembers work?\n',
#  'How does Vastu shastra work?\n',
#  'How does Ola Cafe work?\n',
#  'What does SalesForce want?\n',
#  'Why does Netflix use Amazon EC2?\n',
#  'What does Yahoo own?\n',
#  'How does DRAM work?\n',
#  'How does TrueCaller work?\n',
#  'What is Soul? Where it can Be?\n',
#  'How does HSPX work?\n',
#  'How does Stubhub work?\n',
#  'How does Instagram work?\n',
#  'How does surfcanyon.com work?\n',
#  'How Jimmy Wales think?\n',
#  'Which is better? Business Analytics or Business Intelligence?\n',
#  'What speech-to-text API does HelloTalk use?\n',
#  'Which is better, BitTorrent or uTorrent? And why?\n',
#  'How does ngrok work ?\n',
#  'How does Bigdeal.com work?\n',
#  'How does AI work?\n',
#  'Which is better? IPhone 6s or Samsung Note 5?\n',
#  'Why did Apple make Swift Open Source? How does it affect Android?\n',
#  'How does sarsobiz work?\n',
#  'How does operator.com work?\n',
#  'How does RSA decryption work?\n',
#  'How does Tinder work?\n',
#  'What CMS does Made.com use?\n',
#  'What CMS does forbes.com use?\n',
#  'How does BitTorrent work?\n',
#  'How does Gyroscope work?\n',
#  'Why does Slack use Lato?\n',
#  'How does YouTube Offline work?\n',
#  'How does ngrok work?\n',
#  'How does coupondunia.in work?\n',
#  'How does CB Antenna work?\n',
#  'Where does JK Rowling work?\n',
#  'How does panchang work?\n',
#  'Who is better? Cristiano Ronaldo or Luís Ronaldo?\n',
#  'How does CRISPR work?\n',
#  'How does The Secret work?\n',
#  'How does UPS Will Call work?\n',
#  'Why does 0^0=1 and 0^1=0?\n',
#  'How does Rock Hard X work?\n',
#  'How does Flipboard work?\n',
#  'How does C++ work?\n',
#  'Beer: What is Pilsner? How does it taste?\n',
#  'How does Meebo use CouchDB?\n',
#  'How does purse.io work?\n',
#  'How does IT work?\n',
#  'What is Netflix? How does it work? How much does it cost, etc?\n',
#  'How does Wikipedia work?\n',
#  'How does 4G work?\n',
#  'How does Elon Musk work?\n',
#  'How does Google Allo work?\n',
#  'How does Apple TV AirPlay work?\n',
#  'How does WhatsApp work?\n',
#  'How does AdBlock work?\n',
#  'How does Google AdSense work?\n',
#  'How does Weapon Silencers work?\n',
#  'Why does Google own 466453.com?\n',
#  'How does New Relic work?\n',
#  'How does bugmuncher work?\n',
#  'What does Walmart own?\n',
#  'How does Elasticsearch work?\n',
#  'How does Flipkart work?\n',
#  'Why does Taiwan not like China?\n',
#  'How does Apache Cordova work?\n',
#  'How does Trackr work?\n',
#  'Which is better? Maggi or Yippee?\n',
#  'How does Raspberry Pi work?\n',
#  'How does inselly work?\n',
#  'How does International ACH work?\n',
#  'How does GravityLight work?\n',
#  'How does Google GCM work?\n',
#  'What does Putin want?\n',
#  'How does union-find work?\n',
#  'How does Waze work?\n',
#  'How does Pure Colon Detox work?\n',
#  'How does TF-IDF work?\n',
#  'How does Multi-Level Marketing work ?\n',
#  'How does Wolfram|Alpha work?\n',
#  'How does PlayStation Now work?\n',
#  'How does scamadvisor.com work?\n',
#  'How does word2vec work?\n',
#  'How does Startup India work?\n',
#  'How does HIV cause AIDS?\n',
#  'How does Skyscanner work?\n',
#  'How does Twitter work?\n',
#  'How does Indeed Prime work?\n',
#  'How does Habeas Corpus work?\n',
#  'How does Wall Street work?\n',
#  'How does NEFT/RTGS work?\n',
#  'Who is better? Zidane or Ronaldinho?\n',
#  'What is auroroa? Why does it occur?\n',
#  'How does Hawala work?\n',
#  'How does EMDrive work?\n',
#  'How does Apple Pay work?\n',
#  'How does Garcinia Cambogia work?\n',
#  'How does Samsung Stylus Pen work?\n',
#  'How does review42.com work?\n',
#  'How does Swagbucks work?\n',
#  'How does CloudFlare work?\n',
#  'Why does Black Friday exist?\n',
#  'Who is better? Salman Khan or Shahrukh Khan?\n',
#  'How does TheTake work?\n',
#  'How does Swift work?\n',
#  'How does anarchim work?\n',
#  'How does Developer Auction work?\n',
#  'How does nowmov.com work?\n',
#  'Where does TopCoder Petr work?\n',
#  'How does installerr.com work?\n',
#  'How does Shutterstock work?\n',
#  'How does chatbot work?\n',
#  '6-5=2? What is that?\n',
#  'How does Google Earth work?\n',
#  'How does Adobe Creative Cloud work?\n',
#  'Which is better? Xampp or EasyPHP?\n',
#  'How does WEP work?\n',
#  'How does Quora Moderation work?\n',
#  'Why does PayPal exist?\n',
#  'How does GST work?\n',
#  'Why does NASA use Windows?\n',
#  'How does Lenz Law work?\n',
#  'How does Venmo work?\n',
#  'How does Fast Fourier Transform work?\n',
#  'How does Search Engine Optimization work?\n',
#  'How does Abra work?\n',
#  'How does babyhugz.com work?\n',
#  'How does Hearthstone Arena work?\n',
#  'How does LinkedIn work?\n',
#  'How does PuTTY work?\n',
#  'How does SoundHound work?\n',
#  'How does Zillow Algorithm work?\n',
#  'How does DC++ work?\n',
#  'What does ISIS want?\n',
#  'Why does Easter Bunny exist?\n',
#  'How does Alcoholics Anonymous work?\n',
#  'How does Quora work?\n',
#  'How does Ello work?\n',
#  'Who is better? Neuer or De Gea?\n',
#  'Why does Edward Snowden not like Google Allo?\n',
#  'Why does Tinder work?\n',
#  'How does Gravity exist?\n',
#  'How does how-old.net work?\n',
#  'How does Lyft work?\n',
#  'How does ESP work?\n',
#  'How does Reddit work?\n',
#  'How does PayPal work?\n',
#  'How does Alpha Force Testo work?\n',
#  'How does CIBIL work?\n',
#  'How does allopatric and sympatric speciation?\n',
#  'How does bookmybai.com work?\n',
#  "What's better? Quora or Facebook?\n",
#  'How does Prashant Kishore work?\n',
#  'How does CRISPR/Cas9 work?\n',
#  'How does LSD work?\n',
#  'What is better Uber or Ola? Why?\n',
#  'How does Hibernate work?\n',
#  'How does Malwarebytes Anti-Malware work?\n',
#  'What does TGIF mean? How is it used?\n',
#  'How does socialtrade.biz work?\n',
#  'How does Secret work?\n',
#  'What CMS does Owler.com use?\n',
#  'Why does Jane Street use OCaml?\n',
#  'Whether I do CA or MBA? Which is better?\n',
#  'How does pointerpointer.com work?\n',
#  'How does Find My iPhone work?\n',
#  'How does Marco Arment use Instapaper?\n',
#  'How does SENSEX work?\n',
#  'How does Under Armour work?\n',
#  'Which is better? Vim or gvim?\n',
#  'What does Queen Elizabeth do?\n',
#  'Why does Bloody Mary kill?\n',
#  'Is Python better than Java? Why or why not?\n',
#  "What is Dropbox's corporate slogan? What does it mean?\n",
#  'Why does Jon Snow know nothing?\n',
#  'Where does Bulma live?\n',
#  'Are Sikhs not Hindu?\n',
#  'What does a New World Order mean?\n',
#  "Who should Win 2015 FIFA Ballon D'Or Award?\n",
#  'Is College Works Painting a scam? Why or why not?\n',
#  'How does Viagra or Cialis work?\n',
#  'How does Adblock work? And why is it free?\n',
#  'What does Padfoot mean in Harry Potter?\n',
#  'What does CyberArk do?\n',
#  'Is devolution bad? Why or why not?\n',
#  'Is there Watch Dogs 2?\n',
#  'What does Kakigarden.com do?\n',
#  'Does karma really exist? How does it work?\n',
#  'What does R mean in Vietnamese?\n',
#  'What is State Bank Group Transfer? Is it better than NEFT or RTGS?\n',
#  'What does Emma Watson do?\n',
#  'Where does Simon Pegg live?\n',
#  'What does utualito/utual mean in Spanish?\n',
#  'What does actually IQ mean?\n',
#  "What does Occam's Razor do?\n",
#  'Which Caste does Tank Surname Belong to?\n',
#  'What does Aricent Technologies do?\n',
#  'What does Harsha Bhogle read?\n',
#  'What does Chain do?\n',
#  'What does A2A mean on Quora?\n',
#  'Where does Johnny Depp live?\n',
#  'What does Pivotal do?\n',
#  "How does Samsung Galaxy Note's S Pen work?\n",
#  'What does Snoop Dogg drive?\n',
#  'What does Pay Grade: G-4 mean?\n',
#  "How does Domino's Pizza Tracker work?\n",
#  'What does A2A and FYI mean?\n',
#  'What does the Bretton Woods Agreement mean?\n',
#  'What does this mean?\n',
#  'What does Euglena gracilis do?\n',
#  "Why does Hess's Law work?\n",
#  'What does Anders Kaseorg do?\n',
#  'Why does nobody like Nickelback?\n',
#  'Where does Cristiano Ronaldo live?\n',
#  'Is Zagat better than Yelp? Why or why not?\n',
#  'What is minerd.exe? How does it get into a computer? What does it do? How do I remove it?\n',
#  'What does Apigee do?\n',
#  'Is creditreport.com safe? Why or why not?\n',
#  'Why does 7 Days To Die lag? How can I fix this?\n',
#  'What does adapt.TV do?\n',
#  'What does SQLite do?\n',
#  'In Human, what does Jon Bellion say in Hawaiian?\n',
#  "What is Virgin's corporate slogan? What does it mean?\n",
#  'What does TweetDeck look like?\n',
#  'Is Nice Kicks legit? Why or why not?\n',
#  'Is Obama really Barry Soetoro?\n',
#  "Why doesn't India have Islamic Banks?\n",
#  'Is Milanoo a scam? Why or why not?\n',
#  'What does NantHealth do?\n',
#  "Why does Murphy's Law happen?\n",
#  'Which one is better Linux OS? Ubuntu or Mint?\n',
#  'What does thaachuko/thaachi mean in Tamil?\n',
#  'How does Lost end?\n',
#  'What does Artemis look like?\n',
#  'What is your favorite sloka? What does it mean?\n',
#  'Why does North Korea hate The United States?\n',
#  "What is Microsoft's corporate slogan? What does it mean?\n",
#  'Why does China hate Dalai Lama?\n',
#  'Do you like Wikihow? And why?\n',
#  'Do you like China? And why?\n',
#  'What does 我是法轮大法 mean in English?\n',
#  'What does TweetDeck do?\n',
#  'What is the Hyperloop? How does it work?\n',
#  'What does Trident do?\n',
#  'Which is more stable? CH3-CH2+ or CH2=CH+? And why?\n',
#  'What does jiepang.com do?\n',
#  'Which is better, Play Framework or Spring MVC? How should I decide what to use?\n',
#  "Why doesn't Microsoft Word open? How do you fix it?\n",
#  'What does Automated Insights Wordsmith do?\n',
#  'Why does 0! Equal 1?\n',
#  'I know that?\n',
#  'Which is better: HP Pavilion 15-AU111TX or HP Pavilion 15-AU114TX ? And why?\n',
#  'What does Google Ventures do?\n',
#  'What does Allah mean in Sura 5 Vers 72?\n',
#  'What did you ask/asked? Why?\n',
#  'Why does Hillary Clinton suck?\n',
#  'How does Inuyasha end?\n',
#  'Who uses MathCAD? Why do they use it?\n',
#  'Are there UFOs?\n',
#  'Is Abortion wrong? Why? Why not?\n',
#  'Why does United Nations prefer French?\n',
#  'What does L mean on YouTube?\n',
#  'In Korean, what does oppa mean?\n',
#  'What is The Rapture? When should it happen?\n',
#  'What does SAP actually do?\n',
#  'Why does NATO still exist?\n',
#  'What does FreshBooks.com do?\n',
#  'Attractive Women: What does MILF mean?\n',
#  'Does God exist? If yes, How and where?\n',
#  'If 1+8+9=1 then what is 2+9+8=?\n',
#  "Why doesn't China like Japan?\n",
#  'What is existence? And do we know what it is? Or not?\n',
#  'Was Genesis misunderstood? Is it proof God does Exist?\n',
#  'What does X mean in edX?\n',
#  'Why does Pakistan hate Afghanistan?\n',
#  "Why doesn't Reddit sue 9GAG?\n",
#  'Did Agatha Christie write The Big Four? If not, who did?\n',
#  'Where should I take Master degree of Chemical Engineering? South Korea or Germany? And why?\n',
#  'What does defragmenting do?\n',
#  'What does imOnline do?\n',
#  'What is Faraday cage? How does it work?\n',
#  'Do you like school? Why or why not?\n',
#  'What does TIBCO Spotfire do?\n',
#  'What does The Sandman do?\n',
#  'How does Balaji Vishwanathan know everything?\n',
#  'What does Gordon Ramsay do?\n',
#  'Twitter or Facebook? Which one is better/do you prefer?\n',
#  'Psychology: Is Sheldon Cooper an Aspie? Why or why not?\n',
#  'What is better: Hulu or Netflix? Why?\n',
#  "What is Facebook's corporate slogan? What does it mean?\n",
#  'Should South Asian Nations Unite Together just like European Union ? If suppose It Happens How India will Be Having An Advantage?\n',
#  'What does VMware do?\n',
#  'What does via mean?\n',
#  'Rackspace Cloud vs. Amazon Cloud — which one is better? And why?\n',
#  'What exactly does Java do?\n',
#  'Is Rahul Gandhi really vargin?\n',
#  'What Does X Company Do?: What does Flextrade do?\n',
#  'Is Miami, FL dangerous? Why or why not?\n',
#  'Health Net Basic HMO or Anthem Blue Cross Traditional HMO? Which is better?\n',
#  'What does Carl Icahn do?\n',
#  'Why does Yahoo mail freeze? How do I fix it?\n',
#  'What is malware? What does it do?\n',
#  'How does cbap help?\n',
#  'How does one use Twitter?\n',
#  'Using QR codes? What is it like? Do they work?\n',
#  'Which is better, Java or Python? And how?\n',
#  "How does Apple's iMessage work?\n",
#  'What is chronons? How do you get chronons?\n',
#  'What does Monica Geller mean as 7?\n',
#  'Did paparazzi kill Princess Diana? Why or why not?\n',
#  'Is Daniel Tosh funny? Why or why not?\n',
#  'What does Ashwagandha look like?\n',
#  'What does Xiao Mei mean in Mandarin?\n',
#  'What would Hillary Clinton Have To Do To Serve Time?\n',
#  "What is HP's corporate slogan? What does it mean?\n",
#  'How does A2A pricing work in Quora? How does it increase/decrease?\n',
#  'Who Says True Love Happens only Once?\n',
#  'What does 骚客 mean in English?\n',
#  'How does Listia.com make money? Does it?\n',
#  'Is Amazon better than eBay? and why?\n',
#  'What does Joshua Engel look like?\n',
#  'What does Yellowleg.com do?\n',
#  'Among IIIT Jabalpur and PEC Chandigarh, which is better? Why?\n',
#  'What bank does not use ChexSystems? Why?\n',
#  "Is Indian Army any good? If not why it isn't? Read details/comment?\n",
#  'When does Naruto end?\n',
#  'Are Mexicans really Mestizos?\n',
#  'What does Habibi mean in Arabic?\n',
#  'Did the Big Bang happen? Or not?\n',
#  'What does babel-polyfill do?\n',
#  'How does one know something?\n',
#  'What does Oracle PeopleSoft do?\n',
#  'What is homeopathy? How does it work?\n',
#  'What is ECMAScript exactly? Is it different than JavaScript? Should I learn it?\n',
#  'Why does 1+1=2 and not 3?\n',
#  'Is gravity constant? Why or why not?\n',
#  "What is Dell's corporate slogan? What does it mean?\n",
#  'Which would you prefer, Wayfarers or Aviators? Why?\n',
#  'What did Ptolemy know?\n',
#  'Which one is better: FIITJEE or VMC? Why?\n',
#  "Why doesn't India host Olympics?\n",
#  'Why does the Brexit exist?\n',
#  "Why India doesn't attack China?\n",
#  'Which site is better Paytm or Freecharge or Rechargeitnow? Why?\n',
#  'What does Tiffany Trump do?\n',
#  'How does Quora work, what does it do?\n',
#  'What does Aggregate Knowledge do?\n',
#  'What does THWglobal.com do?\n',
#  'Does Amazon S3 use SSD? If not, then why not? Is cost the issue?\n',
#  'When/where does glycolysis occur? Why?\n',
#  'What does calligraphy? Why is it important?\n',
#  'What does Microsoft Money do?\n',
#  'What is comic timing? What does it mean?\n',
#  'What does SBI IT Officer actually do?\n',
#  'What does gichi mean? How did the term originate?\n',
#  'What TV should I buy- LED or PLASMA?\n',
#  'Is xdating a good website? Why or why not?\n',
#  'Which should I choose SMS Jaipur or AIIMS Jodhpur? Why?\n',
#  'Why does Peter Thiel hate Gawker?\n',
#  'What does Batman do?\n',
#  'What does Jane Street Capital do?\n',
#  'How does Stripe really work? Is it like Paypal?\n',
#  'General Knowledge: What does Dxx mean?\n',
#  'Is Barack Obama actually Barry Soetoro?\n',
#  'Why does Pakistan love Turkey?\n',
#  "What is Amazon's corporate slogan? What does it mean?\n",
#  "How does Facebook's DeepText work?\n",
#  'Is Pulp Fiction overrated? Why or why not?\n',
#  "What is Apple's corporate slogan? What does it mean?\n",
#  'Who did 911?\n',
#  'What is better, Coke or Pepsi? Why?\n',
#  'What does The Honest Company do?\n',
#  'What does this mean in English? 这是被战火践踏过的土地，从今天起，我们要缅怀那片长满鲜花的草地。?\n',
#  'What does SC mean in Facebook?\n',
#  'How did monkeys get to South America from Africa or Asia? Aliens? God? Magic?\n',
#  'Should I upgrade to Windows 10? Why or why not?\n',
#  "Why doesn't Microsoft own Google?\n",
#  'Who is better, Lebron James or Kobe Bryant? Why?\n',
#  'What does Elon Musk read?\n',
#  'What does this Google Doodle mean?\n',
#  'Which is better, Selenium or QTP? Why?\n',
#  "How does Binisoft's Windows Firewall Control work?\n",
#  'Where does Tom Hanks live?\n',
#  'What does Bootstrap.js do?\n',
#  'What does Cognizant Technology Solutions do? Why is it so popular?\n',
#  'What does 鹵水 mean in Chinese?\n',
#  'Do you like Windows 10? Why or why not?\n',
#  'Is Dragon Ball Z overrated? Why or why not?\n',
#  'What does 乐赋唱随 mean in English?\n',
#  'Why does North Korea hate South Korea?\n',
#  'What does Blue Cheese look like?\n',
#  'What port does TunnelBear use? Why?\n',
#  'Why does Arnab Goswami left Times Now?\n',
#  'If 0.7=p/q then what is p+q?\n',
#  'What does Christmas mean you?\n',
#  'What does Wildfire Interactive do?\n',
#  'Where does MyLifeAsEva live?\n',
#  'Which show is better? Friends or HIMYM?\n',
#  'What does VPN mean on iPhone?\n',
#  'Who does Rand Paul look like?\n',
#  'Is Diamond Dallas Page Jewish or not?\n',
#  'Why did Saudi Arabia Target A Doctors Without Borders Hospital In Yemen?\n',
#  'What does GitHub actually do?\n',
#  'Are Semites actually Aryan?\n',
#  'Is Linux better than Windows, or not? Why?\n',
#  'Why does the NuvaRing fail?\n',
#  'Can Xenon make Xenon tetrafluoride? If not, why?\n',
#  'Which is a better Institute: IBS Hyderabad or IBS Mumbai? And why?\n',
#  'Where does Jim Webb live?\n',
#  'Paper degradates? Why? Into what? Is there any way to avoid it?\n',
#  'Do you like Trump? If not, why?\n',
#  'What does the name "Egypt" mean? Where does it originate?\n',
#  'Democracy means what?\n',
#  'Electrical means what?\n',
#  'Why does KTU suck?\n',
#  'What does Wavii do?\n',
#  'Where does Bernie Sanders live?\n',
#  "How does the Incan calendar work? Or doesn't it?\n",
#  'Does Palestine exist, or is it Israel?\n',
#  'What does DeepMind Technologies do?\n',
#  'What does this mean ^^?\n',
#  'Is it Vietnam or Viet Nam?\n',
#  'What is hysterorrhexis? How and why does it occur?\n',
#  "Why doesn't Usain Bolt run 400m?\n",
#  'Why is Mozilla Firefox not responding? How do I fix it?\n',
#  'Why Chinese does not like number 4?\n',
#  'Who is stronger: Vegito or Gogeta? And why?\n',
#  'Are there Asian Jews?\n',
#  'Should I get an Xbox One or PS4? And why?\n',
#  'What should I join-Convergys or Genpact?\n',
#  'What does Symbaloo do?\n',
#  'What is meant by Kernel? What does it do?\n',
#  'Acronyms: What does LP stand for??\n',
#  'What does An Underwriter do?\n',
#  'How You Expect 2017 for Pakistan? What you think?\n',
#  'Do you like threesomes? Why or why not?\n',
#  'Movie and TV Characters: Ferris Bueller or Marty McFly? Which is better?\n',
#  'Why does DNA split?\n',
#  'Which one is better VMC Pitampura or FIITJEE South Delhi? Why?\n',
#  'What does 胖口 mean in English?\n',
#  'What does the Holy Ghost do? What is the Holy Ghost?\n',
#  'What does Netlogon do?\n',
#  'What is the Black Hat SEO? How does it work?\n',
#  'Who is the better Batman? Affleck or Bale?\n',
#  'How does one speak?\n',
#  'What does Aahista mean in English?\n',
#  'What does this mean رؤؤؤؤؤؤؤؤؤؤعة?\n',
#  'Resonance or FIITJEE: Which is better? Why?\n',
#  'Which is better: Xbox or Playstation? Why?\n',
#  'Why does Quora hate Donald J Trump?\n',
#  'What is the Pendleton Act? What did it do?\n',
#  'Your Eye Is 576 Megapixels Camera ? But why You are Asked Wrong Question?\n',
#  'How does Doraemon end?\n',
#  'Is Shell gas good? Why or why not?\n',
#  'What does Postmates do? Who should use this service?\n',
#  'Does HTTP use TCP or UDP? Why?\n',
#  'Do you support PETA? Why or why not?\n',
#  'Who or what is Donald Trump, really?\n',
#  'What Does X Company Do?: What does RingYa do?\n',
#  'What does Jake Wiliams look like?\n',
#  'What does Sauron look like?\n',
#  'Who does he like?\n',
#  "Why doesn't ISIS attack Iran?\n",
#  'Who is a better singer, Udit Narayan or Kumar Shanu? And why?\n',
#  'Which is better: github or phabricator? Why?\n',
#  'Why does North Korea love China?\n',
#  "Why North Korea doesn't have Internet?\n",
#  'Are you single? Why or why not?\n',
#  'What is deep lesioning? How does it help?\n',
#  'Does Gardenia Cambodia really?\n',
#  'What is better? Quora or Yahoo Answers.?\n',
#  'What does Mika mean in Japanese?\n',
#  'What does OUT FOR DELIVERY mean - Snapdeal?\n',
#  'What does the Fox say?\n',
#  'What does DNA do?\n',
#  'Why does Nepal hate India?\n',
#  'Should I buy Redmi 3s prime? Why or why not?\n',
#  'What does Pattern do?\n',
#  'Is the US a superpower? Why or why not?\n',
#  "What is Netflix's corporate slogan? What does it mean?\n",
#  'How did Albert Einstein Study?\n',
#  'Is Allah actually Satan?\n',
#  'Is EOS chapstick good? Why or why not?\n',
#  'Does Richard A. Muller know Richard S. Muller?\n',
#  'Which is better: Uber or Ola? Why?\n',
#  'In Islam, does black magic exist? And if yes to what extent?\n',
#  "How does Amazon's distribution/warehouse work?\n",
#  'Why does time exist?\n',
#  'What does Postmates exactly do?\n',
#  'Is Pikachu a good Pokemon? Why or why not?\n',
#  'What is God? Can someone define God?\n',
#  'Which is better, Omegle or Chatroulette? Why?\n',
#  '1=5,2=25,3=125,4=625,5=? What is the answer?\n',
#  'Which Laptop should I buy? Mac OS or Windows OS?\n',
#  'Who does Ted Cruz look like?\n',
#  "Why doesn't ISIS attack Saudi Arabia?\n",
#  'How does time exist?\n',
#  'What does Canada do right?\n',
#  'How does Quora change you?\n',
#  'What does it mean?\n',
#  'Which is better, PHP or Python? Why?\n',
#  'Where is NSH Delhi? How can I reach there?\n',
#  'FIITJEE or Resonance: Which is better? Why?\n',
#  'In Breaking Bad, why does Walter White poison Brock?\n',
#  'Is WinZip safe? Why or why not?\n',
#  'Nations that do/does otherwise? Which one do I use?\n',
#  'What does なんだよ、こいつは。 mean in Japanese?\n',
#  'What does a KA mean?\n',
#  'What is better according to you- Coca Cola or Pepsi ? why?\n',
#  'What does Blend Labs do?\n',
#  "How does Narendra Modi's Think Tank work?\n",
#  'Which GPU is better? MALI-T860MP2 OR Adreno 405?\n',
#  'What does Marc Bodnick look like?\n',
#  'Who is better: Jay Leno or Jimmy Fallon? Why?\n',
#  "What is Pixar's corporate slogan? What does it mean?\n",
#  'Mobile Web or Mobile Apps? Or both?\n',
#  'Which 61 key Piano is better? Yamaha or Casio?\n',
#  'Services like Wochit or Wibbitz?\n',
#  'Explain what is Hadoop?\n',
#  'What does Cisco Meraki do?\n',
#  'What does Javac.exe do?\n',
#  'Explain what is Sequencefileinputformat?\n',
#  'What does LexisNexis do?\n',
#  'What does Google Voice do?\n',
#  'What exactly does MIT Media Labs do?\n',
#  'Why does guys musterbate?\n',
#  'How does God look like?\n',
#  'What does President Barack Obama think about India?\n',
#  'Why does Microsoft love Linux?\n',
#  'Are there iPhone 7 Mockups?\n',
#  'In Python, what is NumPy? How is it used?\n',
#  'Which one is better, Dev C++ or Eclipse? Why?\n',
#  'What does TCS do?\n',
#  'Clipboard? Where is it?\n',
#  'Why does surface tension exist? Why does it "work"?\n',
#  'What does etc. mean?\n',
#  'What is starch? What function does it have?\n',
#  'What is prorated insurance? How does it work?\n',
#  'Do Shadow Web really exist??\n',
#  'Where does erosion happen? Why?\n',
#  'What does Gumby mean? What is its origin?\n',
#  'What does Clinkle do?\n',
#  'Why does Central Park close?\n',
#  'Do you think god exists? If so where? And why?\n',
#  'What does 50MG quetiapine/Seroquel do?\n',
#  'What is a resistor? What does it do?\n',
#  'What is a choroid? What functions does it have?\n',
#  "What is Reddit's corporate slogan? What does it mean?\n",
#  'What does Find My iPhone do?\n',
#  'What is protoplasm? What purpose does it serve?\n',
#  'What does GoDaddy do?\n',
#  'Can there be multicellular prokaryotes? Why or why not?\n',
#  'How does ola works?\n',
#  'Why does Lex Luthor hate Superman?\n',
#  'How does Tushar Roy teach coding? Who is he?\n',
#  'What does Rowan Atkinson do?\n',
#  'What does geomatics do?\n',
#  'What does IBM do?\n',
#  'What does A2A and OP mean?\n',
#  "What does Hawai'i mean in English?\n",
#  'What makes Rock Music Rock?\n',
#  'What does this means?\n',
#  'Where does Niklas Zennstrom live?\n',
#  'What is UNASUR? What purpose does it serve?\n',
#  'Which is better-GMAT or CAT?\n',
#  'How does Arabic sound?\n',
#  'What does Markmonitor.com do?\n',
#  'Where does Peter Thiel live?\n',
#  'Software that can?\n',
#  'Why does 1*-1=-1,  and -1*-1=1?\n',
#  "Why India doesn't attack Pakistan?\n",
#  'Who is the better politician, Narendra Modi or Arvind Kejriwal? Why???\n',
#  'Explain Sugar is macrostructure or microstructure?\n',
#  'Who is the Dalai Lama? What does Lama indicate?\n',
#  'What does G.I. Stand for?\n',
#  'Will Google buy Quora? Why or why not?\n',
#  'Is Stack Exchange better than Quora? Why or why not?\n',
#  'What does nosey* mean in Japanese?\n',
#  'What does ++ mean in I++?\n',
#  'Do you think Commerce Bank should continue with Retailtainment? If yes why? If no why?\n',
#  'What does Nazi mean in German?\n',
#  "What is Linkedin's corporate slogan? What does it mean?\n",
#  "Why does ISKCON deny Lord Shiva's Supremacy?\n",
#  'Is Hypnotism real? How does it work?\n',
#  'How does Stephen Hawking speak?\n',
#  'What does groupcommerce.com do?\n',
#  'What is The Quiet Revolution? Why did it happen?\n',
#  'Why did SellBuyBook.com Failed?\n',
#  'How do I Hack Clash of Clans? Is it really possible?\n',
#  'Is Eminem better than Jay Z? Why/why not?\n',
#  "Why doesn't Quora use PostgreSQL?\n",
#  'What does Goldman Sachs do?\n',
#  'Is marriage hard? Why or why not?\n',
#  'What feature does erlang have, but scala+akka does not? And vice-versa?\n',
#  'What does downvoting do?\n',
#  'What is Pure Colon Detox? Is it works?\n',
#  'What does the Rosetta Stone say?\n',
#  'Why does Facebook show Instagram?\n',
#  'Are most American Muslims Sunni or Shias? How can I tell?\n',
#  'How does Superman fly?\n',
#  'What does OBC mean in KVPY?\n',
#  'What does Seti do?\n',
#  'Would you recommend Lumosity? Why or why not?\n',
#  'Do dogs sweat? Why or why not?\n',
#  'What does Oxycodone do?\n',
#  'What does Accenture do?\n',
#  'What does superbcrew.com do?\n',
#  'What does ^OG mean on Twitter?\n',
#  'What exactly does salesforcce.com do?\n',
#  'What does SCVNGR do?\n',
#  'What does North Korea do right?\n',
#  'What does Pakistan mean to China?\n',
#  'Do Greek gods exist? Why or why not?\n',
#  'In The Hunt for Red October, why does Ramius defect?\n',
#  'Who does Katy Perry look like?\n',
#  'What does C-SPAN do?\n',
#  'Are switchblades legal in California? Why or why not?\n',
#  'Why did Arnab Goswami Resigned?\n',
#  'Who is better: Messi or Pelé? Why?\n',
#  'What does CloudFlare do?\n',
#  'What is Cyclone Vardah? Please elaborate it?\n',
#  'Does Subramanian Swamy know Chinese/Mandarin?\n',
#  'Who does not use Quora?\n',
#  "Why isn't 0^0=1?\n",
#  'How does myfitnessPal.com make money? or do they?\n',
#  'Why does Russia not join NATO?\n',
#  'What did Alexis St. Martin?\n',
#  "Why doesn't Mark Zuckerberg use Quora?\n",
#  'Which one is better? Canon or Nikon?\n',
#  'What does Jay-Z do?\n',
#  'Is Larry Stylinson real? Why or why not?\n',
#  'Is it shameful…?\n',
#  'Which is better BCA or B. Tech? Why?\n',
#  'Does pH affect buoyancy? If it does, how?\n',
#  'Are you gay? And why?\n',
#  'What does OOP actually mean? Is C language also OOP like C++?\n',
#  'What does hardware mean?\n',
#  'What does Wuthering Heights look like?\n',
#  'Do you make New Years resolutions? Why or why not?\n',
#  'What exactly does the1stmovement.com do?\n',
#  'What does Elon Musk do?\n',
#  'How does Google know everything?\n',
#  "Why doesn't Gary Johnson debate?\n",
#  'Do you prefer Babbel or Duolingo? Why?\n',
#  'What does Vyvanse do?\n',
#  'Why does man need God?\n',
#  'How does one know anything?\n',
#  'Is Indian Film Industry really Global?\n',
#  'Did Krishna like Karna or Arjuna?\n',
#  'Online Auctions: How does BidHere.com work?\n',
#  'What does Hadoop do?\n',
#  'Where does Bashar Al Assad live?\n',
#  'Which is better: Node.js or PHP? Why?\n',
#  'How does DNA split?\n',
#  'What exactly does Amazon AWS do?\n',
#  'What does Groupon do?\n',
#  'Was Reconstruction a failure? Why or why not?\n',
#  'What does Tilt do?\n',
#  'When does it stop?\n',
#  'What exactly does RAM do?\n',
#  'Is skateboarding easy? Why or why not?\n',
#  'What does Bootstrap do?\n',
#  'Which is a better DSLR? Canon EOS70D or Nikon d5500?\n',
#  'What does Forever Living do?\n',
#  'Which one is better, Kopaja or Metromini? Why?\n',
#  'What is macroevolution? How does it differ from microevolution?\n',
#  'Was the Black Panther Party successful? Why or why not?\n',
#  'Why did USA Nuke Japan?\n',
#  'What is the Five-Second Rule? How does it work?\n',
#  'Why does China bully Taiwan?\n',
#  "What is Yahoo's corporate slogan? What does it mean?\n",
#  "How does Tesla's Powerwall work?\n",
#  'What does hey mean?\n',
#  'Why does Pakistan help ISIS?\n',
#  'Why does the US Army exist?\n',
#  'Which is better, Eclipse or Netbeans? Why?\n',
#  'What does radical mean?\n',
#  'What is acupuncture? How does it work?\n',
#  'What does American marketing Association do? How was it established?\n',
#  'Which is better, Redmi Note or Redmi Note 4G? Why?\n',
#  'What does DDR mean in DDR3?\n',
#  'What does Target do?\n',
#  'What is taharrush? How widespread is it? Why do people do it?\n',
#  'What does HTML do?\n',
#  'What does \\U00024d13 mean in Chinese?\n',
#  'What is IBM Bluemix? How does it help developers?\n',
#  'What does P.S. really mean?\n',
#  'What should I code/program?\n',
#  'Do women like cunnilingus? Why, why not?\n',
#  "Why doesn't Siri work?\n",
#  'What is clk.atdmt.com? Is it legit?\n',
#  'What does Tiresias tell Odysseus? Why is this important?\n',
#  'What does 押一付三，先付后用 mean in English?\n',
#  'Are Canada Geese really Canadian?\n',
#  'Is Ethereum better than Bitcoin? Why or why not?\n',
#  "What is Asana's corporate slogan? What does it mean?\n",
#  'Is Rohypnol legal? Why or why not?\n',
#  'Why does China hate India?\n',
#  'What does SMTP do?\n',
#  'What does AA mean in AA制?\n',
#  'What does CodeFights.com exactly do?\n',
#  "What does ''The War Guilt Clause'' mean?\n",
#  'What does Richard Muller think about Michio Kaku?\n',
#  'What does the National Labor Relations Board do?\n',
#  'What does Andy Borowitz think of The Onion?\n',
#  'What India Should do ? Purchase Dassult Rafale or Mig-35 or Stick on Su-30mki?\n',
#  'Atlas or sizmek?\n',
#  'Sausage or Bacon?\n',
#  'What does the FDIC do?\n',
#  'Why does 1 = 1?\n',
#  'Why does Facebook not buy Truecaller?\n',
#  'Where should I buy Moto Z play? Amazon.in or Flipkart or Motorola Store? Which one is better?\n',
#  'What does Jake Williams think about Indians?\n',
#  'Who are better: Indian Muslims or Pakistani Muslims? Why?\n',
#  'What does Barack Obama think of Noam Chomsky?\n',
#  'What does Donald Trump think about Israel?\n',
#  'What is MVC? Is ColdFusion also using MVC?\n',
#  'Is Emma Watson mean?\n',
#  'Who should win the US Presidency? And why?\n',
#  'WHAT does the Resonance Project do?\n',
#  'Which do you find better: Beretta 92FS or Glock 17? Why?\n',
#  'What does the Pope do?\n',
#  'Volkswagen Ameo or Honda Jazz?\n',
#  'Which is better for IT? Jadavpur University or NIT Durgapur?\n',
#  'What does Jimmy Wales think about Wiki Answers?\n',
#  'Does God eat? If so, what does He eat?\n',
#  'Why does -x/x = 1?\n',
#  'Is Facebook dying out? Why or why not?\n',
#  'Is the United States a Socialists country? Why or why not?\n',
#  'What does an HLR do?\n',
#  'How does Marlboro Blend No. 27 and Marlboro Blue compare?\n',
#  'What does dead means?\n',
#  'Do prokaryotic cells have RNA? Why or why not?\n',
#  'What does the Red Cross do?\n',
#  'Is Australia a colony? Why or why not?\n',
#  'In Supernatural, why does Sam say yes to Lucifer?\n',
#  'Which is better, Russian Sukhoi PAK FA T-50 or the US F-22 Raptor? Why?\n',
#  'Is Linux better than Windows? Why?\n',
#  'BenQ ZOWIE XL2720 144Hz 27 or BenQ 1ms GTG XL2720Z?\n',
#  'How does Adrian Lamo hack?\n',
#  'How does CouponDunia actually work?\n',
#  'Is Boost Mobile CDMA or GSM?\n',
#  'Is RMB the same as CNY? Why or why not?\n',
#  'How does Internet Helps in Students Education?\n',
#  'What does Justin Timberlake think of Justin Bieber?\n',
#  'What does current protection mean? How does it work?\n',
#  'What good does Scientology do?\n',
#  'Does Allah mean God?\n',
#  'Is Texila American University accredited? Why or why not?\n',
#  'Why does 1+1 = 2, but not 3 or 4?\n',
#  'What does 「智子は直子に頼んでほしいといっています」mean in Japanese?\n',
#  'In glycolysis, why is ATP used?\n',
#  'What does the Australian Senate do?\n',
#  'How do Iidentify if a verb is Plural or singular? Like what where why etc?\n',
#  'Which religion is more superior, Hinduism or Islam? And why?\n',
#  'What does Eva Kor think of Elie Weisel?\n',
#  'What or who is Lucifer?\n',
#  'Why is Netflix not autoplaying? How can I fix this?\n',
#  'What does an IPO do?\n',
#  'Canon 750D 50mm f/1.8 or 18-55mm?\n',
#  'Why does Microsoft Word not open? How can I fix this?\n',
#  'What does the Mental Health Foundation do?\n',
#  'What does Warren Buffett think about Renaissance?\n',
#  'Where is Shopping cheaper? Singapore or Sri Lanka or Bangkok?\n',
#  'What Language should I learn first? Spanish, Russian or French?\n',
#  'What does Dan Zhang think of Richard Dawkins?\n',
#  'Will you answer this question? Why or why not?\n',
#  'Batman or Superman?\n',
#  'Which is important? Love or money?\n',
#  'What does Russia think about China?\n',
#  'What does Mark Cuban think of Kobe Bryant?\n',
#  'What does Hillary Clinton think of Narendra Modi?\n',
#  'Trump or Clinton?\n',
#  'Are Soap Web Services Stateless or Stateful?\n',
#  'What does Mace Tyrell think of Margaery Tyrell?\n',
#  'What does Sri Sri Ravi Shankar teach?\n',
#  'Do you think Arvind Kejriwal is corrupt ? Why or Why not ?\n',
#  'What does あんた、何やってんの？mean in Japanese?\n',
#  'What does Jimmy Wales think about Bitcoin?\n',
#  'What does Pierre Omidyar think of Jack Ma?\n',
#  'What does Elon Musk think about Virgin Galactic?\n',
#  'What is Maratha Kranti Morcha? What do they really want?\n',
#  'Why does Olympic Athletes Bite their Medals While Posing For Photographs?\n',
#  'Is Quora Republican or Democratic?\n',
#  ...]

# %%
find_nearest(query="Why don't i ask a question myself?", k=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py:720: RuntimeWarning: invalid value encountered in float_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# ["Why do you always answer a question with a question? I don't, or do I?\n",
#  'How do you ask a question in Quora?\n',
#  'How do you ask a good question?\n',
#  'How do I ask a question on Quora and what should I ask?\n',
#  'How do you ask a great question?\n',
#  "Why do I have to ask a girl out? Why can't she ask me?\n",
#  'How do you ask a question?\n',
#  'Why do you have to ask a question on Quora?\n',
#  'How do you answer a question?\n',
#  'How do I ask someone a question on Quora?\n',
#  'Why do you answer a dumb question?\n',
#  "Can I ask a girl out that I don't know?\n",
#  'How do I ask a really great question on Quora?\n',
#  "How do I ask a girl I don't know to fuck?\n",
#  'How do i get myself a girlfriend?\n',
#  'How do you answer a question on Quora?\n',
#  'How do I ask myself the right question to know myself?\n',
#  "Why don't I get a date?\n",
#  'Someone asks you a question you do not want to answer. What do you say?\n',
#  'How do you write a question on Quora?\n',
#  'How do I ask a question on this?\n',
#  'How do people decide when to answer a question on Quora?\n',
#  'How do I know if I am Republican or a Democrat?\n',
#  "How do I know if I'm a jerk?\n",
#  "What should I do if a girl loves me a lot but I don't?\n",
#  'How do you delete a question?\n',
#  "I don't have a job.please advice what I do? 50,000rs.salary?\n",
#  "How can I ask for a job to a person I don't even know?\n",
#  'How do I get a question posted?\n',
#  'How do I know if I am a Democrat or Republican?\n',
#  "How do I start a conversation with a girl I don't know?\n",
#  "Is it ok to ask out a girl who I don't know?\n",
#  'What does it mean to ask a right question?\n',
#  'How do you delete a question from Quora?\n',
#  'How do you find out who asked a question on Quora?\n',
#  'Why do I question myself about this?\n',
#  'How do you learn a person?\n',
#  'How do you answer a questions on Quora?\n',
#  "When a friend of mine asks me, what do I want to do, I'm clueless. How can I solve this?\n",
#  'How do you delete a question on Quora?\n',
#  'You meet God and you can ask him only one yes or no question. What do you ask?\n',
#  'How do I know if a girl really like me?\n',
#  'How do you post a question on Quora?\n',
#  'How do you tell a good answer from a bad answer on Quora?\n',
#  'What do you do when you have a headache?\n',
#  'If you could ask God a question, what would you ask?\n',
#  'How do I write a one page Bio about myself?\n',
#  'W do people give a shit?\n',
#  'How do I ask someone on a date?\n',
#  'How do I know if a Chinese girl likes me or not?\n',
#  'If I ask a question anonymously, do I get credits when people follow it?\n',
#  "How do I How to prove that you don't have a crush on someone when you do?\n",
#  'Why do I ask this question?\n',
#  'How do you do a 3 way call on an iPhone?\n',
#  'How do I ask a girl on a date without asking?\n',
#  'I know a girl likes me but how do I start conversation?\n',
#  "Why don't my questions get seen or answered a lot?\n",
#  'When you ask a question on Quora, how often do you receive a useful answer?\n',
#  'How should I ask a question on Quora and how do I get the answer?\n',
#  'How do I know if a guy likes me or not?\n',
#  'How do I find out if a girl likes/loves me?\n',
#  "Some people ask lengthy questions on Quora. Why won't Quora let me do this?\n",
#  'How do I know if I like a book or not?\n',
#  'How do I ask a question in Quora?\n',
#  "What should I do if I can't become a doctor?\n",
#  'What should I do if I like a girl?\n',
#  'Why do people give a shit?\n',
#  'How do you write a good answer on Quora?\n',
#  'How do you explain Gödels Incompleteness Theorem to a lay-person?\n',
#  'How do you get a Purple Heart?\n',
#  'Why do people give a fuck?\n',
#  'How do you answer this question?\n',
#  'How do you give a fuck?\n',
#  "I don't have a friend?\n",
#  'What do you talk to a girl about?\n',
#  'I want a boyfriend what should I do?\n',
#  "Why don't I ever get a girl?\n",
#  'What should I do about a girl I like?\n',
#  'How do you ask a girl out on Snapchat?\n',
#  'What does it take to ask a popular Quora question?\n',
#  'How do you ask someone out on Quora?\n',
#  "I don't know if a girl loves me or not. How can I tell?\n",
#  'How do I know if I like a girl or not?\n',
#  "I have a crush on a boy, I didn't do anything wrong to him but he hate me a lot, what can I do?\n",
#  "Why don't I have a boyfriend?\n",
#  'Very few people answer my question on Quora, what do I do?\n',
#  'How do I ask questions in a smart way?\n',
#  "Why don't people answer me on Quora?\n",
#  'How do I know if I like a girl?\n',
#  "Why don't atheists have a so sure answer?\n",
#  'How do I know if I love a person?\n',
#  'How do I forget a person ?\n',
#  'What do my parents know about me that I do not know?\n',
#  'Why do people ask questions on Quora but do nothing?\n',
#  "I am a closet Christian. How do I tell my gay friends so they don't hate me?\n",
#  'How do I make a Healthy Pizza? Can anyone tell me?\n',
#  'How do I know if a guy like me?\n',
#  "Is this Kazakh? How come I don't understand a word they say?\n",
#  'What do you know about Turkey as a country? What do you think about Turkish people?\n',
#  'What do you think about buying a Mac Mini?\n',
#  'How do you get a Lamborghini?\n',
#  'How do I form a question with do and did?\n',
#  'How do I know if I want to be a doctor?\n',
#  'How do you find a Spiritual Guru?\n',
#  'Would you like to ask me a question?\n',
#  'I want to ask a question to a specific person on Quora, what I have to do?\n',
#  "How do I start a random conversation with a girl I don't know?\n",
#  "In a job interview, how do I answer a question asking me why I'm unique?\n",
#  'How do you ask a shy guy out?\n',
#  'What can one do about PTSD?\n',
#  'What do you think about a Prince Albert piercing?\n',
#  "How do I accept that I'm a loser?\n",
#  'What does downvoting a question do?\n',
#  'How do I know if a girl really trust me?\n',
#  'How do I get a guy I like to think about me?\n',
#  "How can I ask someone I don't know to mentor me?\n",
#  'How do I ask a girl out?\n',
#  'What should i do get over a girl?\n',
#  "How do I talk to a girl I like but don't know?\n",
#  'How do I ask a question on Quora properly?\n',
#  'How do you come to a conclusion about something?\n',
#  'Being a girl, what do you think about me?\n',
#  'What do you do when you have a crush on someone?\n',
#  'How do I know if I have a past life?\n',
#  'What does a Content Marketing Strategist really do?\n',
#  'What should you not do on a first date?\n',
#  "How do I start a conversation with someone who doesn't know me?\n",
#  'How do I train myself to ask good questions?\n',
#  'How do I know if I am a narcissist or not?\n',
#  'How do I answer interviewers if they ask me if I am a U.S citizen ?\n',
#  'How do I ask a girl out on Quora?\n',
#  'How do I talk to a girl I like?\n',
#  'What do people think about Jesus, do you believe there is a Jesus?\n',
#  '“How do I ask a question in Quora? I need the format. because it is asking for edit every time I ask a question”.\n',
#  "How do you talk to a girl if you don't know her?\n",
#  'As a Muslim, why do you think I should accept Islam?\n',
#  "Why don't you have a girlfriend?\n",
#  'How do I ask a girl out.\n',
#  'How do you take a screenshot on Windows 10?\n',
#  'How do you use a Pax Vaporizer?\n',
#  'How do I find myself a job?\n',
#  "I don't have no question?\n",
#  "How do I unlike a photo on Instagram if I don't follow the person anymore?\n",
#  "Why don't I have a girlfriend?\n",
#  'How do you answer when people ask you on why you do not have a girlfriend / boyfriend?\n',
#  'How can one do a thought experiment?\n',
#  'How do I know that a girl loves me or not?\n',
#  'How do i know if someone loves me?\n',
#  "I like a girl but I'm scared to ask her out. What should I do?\n",
#  'How do I know if a guy at work likes me?\n',
#  'How do I ask a question on Quora?\n',
#  'How do I tell a guy I like him?\n',
#  "How do I tell a girl that I don't know, I like her?\n",
#  'Where do I know myself?\n',
#  "Why don't I get a job call?\n",
#  'How do I know if I have a crush on a girl?\n',
#  "I'm a guy. If I ask out a girl and she says no, how do I make things not awkward?\n",
#  'How do you tell if a Rolex Oyster Perpetual is real?\n',
#  'How do I know if I have a child?\n',
#  'Why do you ask questions on Quora?\n',
#  'How do you tell a Japanese person from a Chinese one?\n',
#  'When you write a rhetorical question, do you follow it with a question mark or a period?\n',
#  'Why do people say "I just have a quick question"?\n',
#  'How do you *as a customer* feel about value-based pricing?\n',
#  "What do I do if I can't verify my Instagram with a phone number?\n",
#  'When asking a girl to prom, what do you say or do if she says no?\n',
#  'How do you fix a bad ESN number?\n',
#  'How do I answer to this question?\n',
#  'How do I know if I am a pervert?\n',
#  'How do I get you to answer this question?\n',
#  'How do I know if a girl likes me or not by Texting?\n',
#  "What questions should i ask myself to figure out if i'm a transgender woman or not?\n",
#  "I want to get a motorbike but my parents don't want me to. I'm 18, what do I do?\n",
#  'What do you think about Donald Trump pick?\n',
#  "I don't have a girlfriend, what should I do to make one?\n",
#  'What should you do to get a question trending on Quora?\n',
#  "Why can't you delete a Quora question?\n",
#  "I'm 28 and still don't have a self-identity. How do I find it?\n",
#  'What do you think a life coach does?\n',
#  'Why do I have to ask questions here?\n',
#  'If you could ask one question to Elon Musk, what would you ask?\n',
#  'I cannot speak clearly with people? Actually I am a student \\U0001f601 when sir ask me question I star stuterring . So, can you help me?\n',
#  'How do you find a girlfriend?\n',
#  "How do I message to a girl who doesn't know me?\n",
#  'What do you eat on a Keto Diet?\n',
#  'How do you think like a genius?\n',
#  'How do I tell a girl if I am not interested?\n',
#  'How do I ask a question on Yahoo?\n',
#  'How do you judge a person?\n',
#  "Why don't Jimmy Wales answer my questions?\n",
#  "Why does it bother me that guys don't ask me out?\n",
#  "How do you know you don't want to do a PhD?\n",
#  'What do a Pakistani will tell when someone ask them about "History of Pakistan"?\n',
#  'How do I get a girl for myself?\n',
#  'How do you answer a leading question?\n',
#  'How do I to know myself?\n',
#  "I like a guy but I don't think he likes me back. What should I do?\n",
#  "How should I ask a girl I don't know for her number?\n",
#  'I always wanted to do a threesome. Is that wrong?\n',
#  'How do I get a shy guy to ask me out?\n',
#  'How do I let a guy know I like him?\n',
#  "What do you do when you can't find a solution to an algorithms problem? And what do you do when you read the solution?\n",
#  'Why do people never answer my question on Quora?\n',
#  "What should I do if I can't stop thinking about a girl?\n",
#  'How do I get a shy girl to ask me out?\n',
#  "How do I know if I'm a narcissist?\n",
#  "I am a young 20-year-old. I don't know what I want do as a career. What should I do?\n",
#  'How do I ask a question on Yahoo Answers?\n',
#  'How do I write a CV and what do I include in one?\n',
#  'Why should one do a PhD?\n',
#  'What should I do if I hate myself?\n',
#  'How do I find a good English name for myself?\n',
#  'How do you get a girl to ask you out?\n',
#  'How do you find a good doctor?\n',
#  "I'm 21 and dont have a purpose what should I do?\n",
#  "Why don't people answer my question on Quora?\n",
#  'Where do you ask questions in Quora?\n',
#  'How do I know if I love myself?\n',
#  'How do I ask a girl for one night stand?\n',
#  'My family dislike me what should I do?\n',
#  'What do you do if you get a fake rupee note?\n',
#  'I would love to give a TED talk. What do I do?\n',
#  'How do you ask a girl to have sex?\n',
#  'What do I do if I forgot my iTunes security question?\n',
#  'What should you do if you ask an instructor a question in class and they ask "does this make sense?" after explaining, and you still don\'t get it?\n',
#  'How can I stop Quora asking me to answer a particular question?\n',
#  'How do I get a guy to ask me out?\n',
#  "How do I write a good essay fast on a topic I don't care about?\n",
#  'How can I ask a particular person to answer my question on Quora?\n',
#  'what do you suggest me to do next ? i want to be a Bigdata consultant.\n',
#  'In Star Wars, why do you need a Death Star?\n',
#  'How do I tell if a guy likes me?\n',
#  "I don't understand what a Muslim or Islam is, can you explain?\n",
#  'How do you delete a question you asked on Quora\n',
#  'How do I ask someone out?\n',
#  'How do I delete a question from Quora?\n',
#  'What do I do if a girl rejects me on a date, but I really want to date her?\n',
#  'How do I know what I have to ask?\n',
#  "What's a question you've always wanted to ask?\n",
#  'How do you think about Chinese? And if you want to marry a Chinese people?\n',
#  'What do I need to know about dating a Dane?\n',
#  'Why do people always ask me where I am from?\n',
#  "How do I become a DJ if I don't know where to start?\n",
#  'How do I know whether a girl likes me?\n',
#  'Why would you do bad things?\n',
#  'How do I answer a question on Quora?\n',
#  'How exactly do you hack a website/database?\n',
#  'How do you type a facepalm in text?\n',
#  "Why do people call me Genius and I don't feel like one?\n",
#  "I just can't insert a tampon. How do I do it?\n",
#  "I love a girl but I don't know how to tell her. What should I do?\n",
#  "What do I do when people ask me questions like 'why', 'when' and 'how' if I am yet to figure out the answer myself? How should I reply to them?\n",
#  'How do you think a World War III would play out?\n',
#  "What should I do? My parents don't let me do anything with my friends, and I don't have a life!\n",
#  'What do you do when you have a boring girlfriend?\n',
#  'What can I do if my boyfriend ignore me once?\n',
#  'When you see a notice on a question you are answering has a Quora moderation/bot message saying; “This question needs improving.” What do you do?\n',
#  'How do I know if a girl likes me back or not?\n',
#  'What should I do if I feel like everyone hates me? Am I going into a depression? What can I do not to hate myself?\n',
#  "I'm 13 how do I convince my parents to let me have a Instagram?\n",
#  'How do I tell a kid to stop lying?\n',
#  'How do you use Netflix on a Chromebook?\n',
#  'How do you know that you want to do a PhD?\n',
#  'How do you delete a question or an answer on Quora?\n',
#  'How do I know if a person is lazy?\n',
#  'How do I leave a person I love?\n',
#  'How do I know someone answered me on Quora?\n',
#  'How do I find a job that I can do well?\n',
#  'How do I accept that I am a loser?\n',
#  'What do I do when Quora tells me to improve a question?\n',
#  "I'm a shy guy. What should I do?\n",
#  'What does it feel like to ask a question on Quora and have no one answer?\n',
#  'How do I figure out who posted a certain question?\n',
#  'When do you feel like a loser?\n',
#  "What should I do if a girl doesn't respond to a text?\n",
#  'How do I hate a good person?\n',
#  "What do I do if a girl doesn't know if she likes me or not?\n",
#  'What exactly do you do for a living?\n',
#  'How do you tell whether a fruit is sweet/ripe?\n',
#  'I feel like a loser, what should I do?\n',
#  'Islam: What do I do as a Muslim if someone slandered me then found out the truth?\n',
#  'How do you ask a girl out on a date?\n',
#  "What should I do if people don't love me for what I am?\n",
#  "Which question can't be answered with a yes or a no?\n",
#  'How do I tell if I have a lisp?\n',
#  'How do you tell a scary story?\n',
#  'What do you do if you had a bad dream?\n',
#  "How do I handle a relationship where I am told I don't talk enough?\n",
#  "How do I know if I've been asked to answer a question on Quora?\n",
#  "What do you do if you have a crush on someone and they don't know?\n",
#  "Why do I think my parents don't care about me?\n",
#  'How do I find right person for me?\n',
#  'How do I say when people ask me rude question?\n',
#  "I want a big brother, but I don't have one. What do I do?\n",
#  "How do I make questions on Quora? I really don't know! How do I do it?\n",
#  'How do you get Skype on a PS Vita?\n',
#  'How do I tell if a girl I sit next to likes me?\n',
#  "How do I prove I'm a High Priestess?\n",
#  'How do I know if I really want to become a doctor?\n',
#  'How not to ask a question on Quora?\n',
#  "If a person doesn't know what to do in life? What should he\\she do?\n",
#  'How do you take apart a Bowflex?\n',
#  'How do I learn to ask the right questions?\n',
#  'How do I get a guy?\n',
#  "Why doesn't Quora require a reason to ask a question anonymously?\n",
#  'What do you know? Ell me something about voluspa?\n',
#  "I asked a girl out. She rejected me but now she loves me. What shall I do now - I don't know what to do?\n",
#  'How do I ask a question on Stack Overflow?\n',
#  'How do I delete an answer for a question that I asked on Quora?\n',
#  'How do you do this SAT math question?\n',
#  'How do you call someone on a computer?\n',
#  'How do I tell a guy I like/care for him?\n',
#  'How do you know if you like a book or not?\n',
#  "I have a crush on a girl. But she doesn't care about me. She doesn't even know me. She has a boyfriend now. What do I do?\n",
#  'Is it a sin to cry? Why do people get mad when I cry?\n',
#  'What would you do if you find a Death Note?\n',
#  "Why don't I get a girlfriend?\n",
#  'If you have a tattoo, do you regret it? Why or why not?\n',
#  'How do I unfollow a question I asked on Quora?\n',
#  'What a hypocrite person can do?\n',
#  'How/When did you figure out what you wanted to do as a career?\n',
#  'How do you be a good person?\n',
#  'I think I like someone. What should I do?\n',
#  'Why do people ask questions that they know the answer to?\n',
#  'What do you know about Turkey?\n',
#  "What do you do when things don't go as planned?\n",
#  'Why do I ask big questions and never care about the answers?\n',
#  'What would be a silly question to ask in Quora?\n',
#  'How do I start a conversation with a girl after saying "hi"? What should be the next question to ask or how do I not bore a girl in the conversation?\n',
#  'What do you feel when you see a Christian cross?\n',
#  'What do you think about FutureLearn.com?\n',
#  'How do you know someone?\n',
#  'How do I ask a girl out for a date?\n',
#  'What do you think about Fantastic Beasts?\n',
#  'What do you think about Packtwo.com?\n',
#  'What do you think about Selena Gomez?\n',
#  "How do I know if a girl I'm talking to has a crush on me?\n",
#  "Any ideas on what to do if I'm bored?\n",
#  'How do you ask someone out nowadays?\n',
#  'How do I find out if I have a warrent?\n',
#  "How not to feel bad when I don't finish a book?\n",
#  'How do you take a screenshot on a HTC One?\n',
#  'How do you find Singapore?\n',
#  'What do you think about?\n',
#  'What do you think about Cambodia?\n',
#  'What can I do with a Google Chromebook?\n',
#  "Why don't you like Lionel Messi?\n",
#  "Why doesn't anybody ask me out?\n",
#  'On a date, what should I do to make a girl fall for me?\n',
#  'How do I find the most upvoted answer on a particular question?\n',
#  'What do I do if I am getting spam emails from myself? How do I make them stop?\n',
#  "What do you do if you don't have any friends?\n",
#  'I feel like a failure, what should I do?\n',
#  'How do I get a boyfriend?\n',
#  "I like a girl, but I don't know how to tell her that?\n",
#  'What do you think about iOS 10?\n',
#  'What do you think about iOS 8.3?\n',
#  'How can I ask someone to answer a question on Quora?\n',
#  "I want a big brother, but I'm a young teenager and I can't find one. How do I find one?\n",
#  'How can I ask a question which makes people think?\n',
#  "Why do I feel that everyone around me knows something about me that I don't know about myself? How can I find out? What am I missing?\n",
#  'How do you find the Mangal Dosha?\n',
#  'Can u tell me some general information about some things which I do not know?\n',
#  'How do you get an upvoted answer on Quora?\n',
#  'How do I know if a boy likes you?\n',
#  'How do I get a Universal International Freephone Number?\n',
#  'How do I convince my parents to let me quit a sport?\n',
#  'How do I know that a person is lying to me?\n',
#  'What do you know about self?\n',
#  'How can I come to know whether a girl likes me?\n',
#  'How do I know whether a guy is cheating on me or no?\n',
#  'What do you think about Chinese New Year?\n',
#  "Why do I feel like I don't know myself?\n",
#  'What do you think about Universal Basic Income?\n',
#  'How do know when a girl likes you?\n',
#  'What do you think about attn.me?\n',
#  'How do people treat you differently when you start a blog? How do bloggers feel about it?\n',
#  "I want to have a threesome but my boyfriend doesn't. What do I do?\n",
#  "How can I know if I don't have a soul?\n",
#  'How do I clarify a question in Quora?\n',
#  "Why don't I get answers to sexual questions I ask on Quora?\n",
#  'How do you go about finding a good doctor?\n',
#  'How do I get a Quora Account?\n',
#  'What do you think about Slyce.it?\n',
#  'How do I know that someone loves me?\n',
#  'How do I know if a girl really loves me?\n',
#  'How do you find out if a girl has a boyfriend?\n',
#  'Can anyone ask and answer a same question in Quora?\n',
#  "Why don't you use Quora?\n",
#  "Why doesn't anyone ever ask me to answer questions?\n",
#  'Why do you want to be a CA?\n',
#  'How do you explain Coriolis force to a child?\n',
#  'How do you tell a girl you like her a lot?\n',
#  'I want to start a lively argument on Quora. How do I do it?\n',
#  'What should I do on a Saturday?\n',
#  'What do you know about China?\n',
#  'What do you think about Nikky Haley?\n',
#  "Why do some people told me that I am pretty, but I personally don't think so?\n",
#  'Are there Quorans who ask a question and answer it themselves?\n',
#  'In Minecraft, how do you make a book?\n',
#  'How do I take a picture of myself?\n',
#  'What do you think about Muslims?\n',
#  'If I know the answer to a question, then why would I ask it on Quora?\n',
#  "Whenever I ask my husband why he loves me, he can't come up with anything legitimate. What do you/your spouse say to this question?\n",
#  "How do I know if someone's American?\n",
#  'How do you write longer details for a Quora question?\n',
#  'What do I do when someone is being mean to me?\n',
#  'How can I forget about a problem?\n',
#  'How do you make Quora a better place?\n',
#  'Why do people ask questions what they ask?\n',
#  "What should I do if i don't know what i want to do with my life?\n",
#  'What do you think about Hillary Clinton 2016?\n',
#  'How do I know if a girl loves me?\n',
#  'Why do people call it a cock?\n',
#  "Why don't people reply to my questions?\n",
#  'As a Canadian, how do you feel about a Trump presidency?\n',
#  'How do I get a good friend?\n',
#  'How do I know if a shy girl likes me?\n',
#  'How do you know if you have a bad memory?\n',
#  "Why don't my questions get any answer?\n",
#  'How do you start a Business India?\n',
#  'How do you ask a guy friend to hang out?\n',
#  'Why do my questions do not get many answers?\n',
#  'How do you find a P-value in Microsoft Excel?\n',
#  'Why do people always believe a hypocrite?\n',
#  'How do I get a fuck buddy?\n',
#  'I have a crush on a girl. What should I do?\n',
#  'How do I get a girl that friendzone me?\n',
#  'Why does Quora insist that I should ask a question?\n',
#  'How do I forget a loved one?\n',
#  'Am I worthless if I do not know what I wanted to do in my life?\n',
#  'How do I know if someone is following me?\n',
#  'What should i do if i do not like my new job?\n',
#  'How do you feel about Sri Lanka? What do you know about Sri Lanka?\n',
#  'How do you talk to a girl like a friend?\n',
#  'What should a person do to feel happy?\n',
#  'How do you find Chhattisgarh News Update?\n',
#  'How do I find a good girlfriend?\n',
#  'I have no friends. What should I do about it?\n',
#  'What are some questions to ask a girl you like?\n',
#  'If he says to me "I don\'t care what you do, just make sure I don\'t catch you and wear a condom" supposed to mean?\n',
#  'What question do you hate to answer and why so?\n',
#  'Should I marry a person I love but do not trust?\n',
#  'What are things not to do on a first date?\n',
#  'What should I do if I have a really annoying voice?\n',
#  "Quora moderation sent me a message and told me that they removed my anonymity, yet I don't think I did anything wrong. What should I do?\n",
#  'How do you find Drawberry.com?\n',
#  'How do I know if a guy has a crush on me or not?\n',
#  'How do you run FL Studio on a Mac?\n',
#  'What do you like about China?\n',
#  'What can I do so that some girl might have a crush on me?\n',
#  'What do you think about Ixconverter.net?\n',
#  'How do I know if I have a concussion?\n',
#  'How do I ask a girl to date me ?\n',
#  'I ask God questions but he never answers. How do I get him to answer me?\n',
#  'What do you think about iOS 7?\n',
#  'How do you report a question? I only see an option to downvote it. Can a question be reported?\n',
#  'What is a Freemason and what do they do?\n',
#  "What does it say about a professor if they don't have postdocs?\n",
#  'What do you think about DotA/DotA2?\n',
#  'How do I know if a guy likes me in office?\n',
#  'How do you get over a girl?\n',
#  'What do you think about getkey.com?\n',
#  'How do you find a problem to solve it?\n',
#  'What do you know about Tunisian Girls?\n',
#  'How do I learn all I need to know about a certain gun?\n',
#  'How do you become a web/developer?\n',
#  'How do I get Jimmy Wales to answer my question on Quora?\n',
#  'How can I ask someone a personal question on Quora?\n',
#  "What don't you like about Quora?\n",
#  'How do you uncollapse an answer?\n',
#  'Why do I have so many questions to ask?\n',
#  'How do you buy a FedEx route?\n',
#  'How do I take a right decision?\n',
#  'How do you find a tutor in India?\n',
#  'How do you get over a boy?\n',
#  'Why do I only love myself?\n',
#  'How do I know if someone actually wants to talk to me?\n',
#  'How do you know if a person is lying?\n',
#  'How do you know if someone is a psychopath?\n',
#  'Why do guys not approach me?\n',
#  'What do you know about Area 51?\n',
#  'What do you think about kabali?\n',
#  'How do I find love but not in a person?\n',
#  "A girl likes me but I don't like her. What should I do?\n",
#  'How do you get a guy to take you seriously?\n',
#  'I want to write a book? What should I do?\n',
#  'What do you think about Minimalism?\n',
#  'How do I ask my parents permission when I know they will say no?\n',
#  "I want to start a local fitness mastermind group/community. I just don't know how. What things can I do?\n",
#  'How do I make a girl talk to me more?\n',
#  'Why does Quora ask me to edit every question I ask?\n',
#  'What do you think about Privatoria.net?\n',
#  'What should I do if I have no one to talk to?\n',
#  'How do you feel about Melisandre?\n',
#  'How do I tell if some one is lying to you?\n',
#  'How do I tell if a girl wants me to take her on a date?\n',
#  'How do you add photo to a Quora question?\n',
#  "Will people think I'm weird/loner/hiding something if I don't use Facebook/Instagram/social media?\n",
#  'Why do people hate to work on a Friday?\n',
#  'What do you like about Facebook?\n',
#  'What do you call a person who lets things get to them?\n',
#  "What do I do if my crush won't add me back on Snapchat?\n",
#  'How can I know what should I do for a living?\n',
#  'Why do certain people answer a question with a question instead of just giving you a straight answer?\n',
#  'I want to write a book. What can I do?\n',
#  'I believe I am in a relationship with a narcissist. How do I get out? Does anyone have any advice?\n',
#  'How do I get a physique like Hrithik Roshan?\n',
#  "How can I know a girl likes me if I don't see her that often?\n",
#  'How do you write a CV without experience?\n',
#  'What should I do if I want to date a girl?\n',
#  'How do I find questions on Quora which have no answers?\n',
#  'What do you think about AliExpress?\n',
#  'What should a dentist do if they like a patient?\n',
#  'How do you Photoshop something into a picture?\n',
#  'Why do people tell me bad things others say about me?\n',
#  'Nations that do/does otherwise? Which one do I use?\n',
#  'What do you think about Quora?\n',
#  'How do I get a Job?\n',
#  "I love a girl and I don't know if she loves me. What should I do?\n",
#  "Today my friend asked me how I know I'm bisexual if I've never dated a guy. How do I tell him that I don't need to?\n",
#  'How do I ask a girl out even though I know that she probably likes me?\n',
#  'Stuck in a lie, what should I do?\n',
#  'What wrong did God do to you besides giving you a life?\n',
#  'What is wrong with me? Why do I get angry at small things? Why do I want to be left alone always?\n',
#  'What do you do when you are in a bad mood?\n',
#  'How do I ask a girl for coffee?\n',
#  'How do I know if a boy loves me?\n',
#  "Why do I want to cry when people ask if I'm okay?\n",
#  'What do you think I should do?\n',
#  'Why do people question so much?\n',
#  'How do I get close to a guy I like?\n',
#  'How do I find the right person for me?\n',
#  "Why do people ask questions for which they don't want to know the answer?\n",
#  "Why doesn't everyone I ask to answer a question answer it on Quora?\n",
#  'Why do people assume that I am a virgin?\n',
#  'What do you think about Zootopia?\n',
#  'how do get into Offshore drilling, i want to be a Materials Coordinator. can i start as a store keeper ? do i need to do any courses ?\n',
#  "Why don't you use Facebook?\n",
#  'How would I know what I like to do?\n',
#  'How much do you need to start a restaurant?\n',
#  'How do you know if someone is a materialist?\n',
#  'How do I forget a girl I have feelings for?\n',
#  'I want a girlfriend. What should I do?\n',
#  "Why don't people give me a chance to get to know them?\n",
#  'Why do you want to be a doctor?\n',
#  "What can you do if you just can't forget a person no matter how hard you try?\n",
#  'How do you take picture on a MacBook?\n',
#  'How do I stop giving a fuck about what others think of me?\n',
#  'Public opinion: as a Bulgarian, what do you think about the EU?\n',
#  'How do you know when a woman likes you?\n',
#  "Why can't I ask people to answer my question on Quora?\n",
#  'Why do I feel awkward talking to a girl when someone is around? How do I improve?\n',
#  'What do you think about Memrise?\n',
#  "How do I get over a guy who doesn't love me?\n",
#  'How do I know that I have a child?\n',
#  'How do I find someone on Quora?\n',
#  "I am a guy. I don't know what to talk about when I meet someone for the first time. What should I do?\n",
#  'What do you know about Lotus Temple?\n',
#  'Do you think do I have a bad memory?\n',
#  "How do you know what you want to be if you don't have a life?\n",
#  'What should I do to make my parents understand me?\n',
#  'What do you think about Serbs?\n',
#  'How do I get a girl to like me?\n',
#  'What do I talk with a girl?\n',
#  'How do I take a screenshot with C/C++?\n',
#  "How do I get a girlfriend if I'm shy?\n",
#  'What do i do after my MBBS ?\n',
#  "How do I know that I'm ready for a relationship?\n",
#  'What should I do when I want a relationship so bad?\n',
#  'What do you think about Galaxy Note 7; Is this a future phone ?\n',
#  'I feel like a loser. What should I do?\n',
#  'What happens if you tell a cop you do drugs?\n',
#  'How do I know that my crush likes me or not?\n',
#  'What can I do to have a conversation with a girl I like?\n',
#  'How do I know if a guy only wants me sexually?\n',
#  'How do I talk to a girl without knowing her?\n',
#  'How do I get Richard Muller answer my questions?\n',
#  "I don't think I'm a smart person. Why do so many other people call me intelligent when really I'm not? Are they confused? Wishful thinking?\n",
#  'How do I find a good PHP Lead Web Developer?\n',
#  'What can I do if I am not getting answers on Quora?\n',
#  'How do you know if you have a crush on a girl?\n',
#  'How do you add a picture to a question in Quora?\n',
#  'When should you downvote a question?\n',
#  'What do you think about Quora Policies?\n',
#  'What can I do when someone blocked me on Viber?\n',
#  'What do you think about Sufism?\n',
#  'How do I ask a girl out for sex?\n',
#  'What should I do to date a girl?\n',
#  'How do I ask out a girl for a one night stand?\n',
#  'Why do some people pretend to be a friend?\n',
#  'What should I do if I have a crush on my professor?\n',
#  'How do you write a diary?\n',
#  'What should I do if I missed a dose of Seroquel?\n',
#  'What do you think about Panama as a country?\n',
#  'How do I know if a woman likes me?\n',
#  'Should things only be done for a reason? Is it bad to do things for no reason?\n',
#  'How do I find any particular answer on Quora?\n',
#  'How do you feel about self-disclosure?\n',
#  "What do you do, when your parents don't understand you?\n",
#  'What things can you not do?\n',
#  "How do you ask someone you'd like to give them a blow job?\n",
#  'What should you do when you feel like a loser?\n',
#  'How do busy people like Jimmy Wales, Richard Muller find time to answer questions on Quora?\n',
#  'How do I figure out what I really like to do?\n',
#  "What am I missing if I don't have a boyfriend?\n",
#  'What should I do if I feel like I have no life?\n',
#  'What do you think about Indonesian?\n',
#  'What do you think about Che Guevara?\n',
#  'How do you tell if you have a broken nose?\n',
#  'What do you think about Turkish?\n',
#  'What do you think about yourself as a human?\n',
#  'How do I find people I know on Quora?\n',
#  "What can I do if I'm bored on a Friday night?\n",
#  'Why do people question answer a question with a question?\n',
#  'What do you know about Afghanistan?\n',
#  'What do you think about Bitcoin?\n',
#  "What are some questions you don't want to ask?\n",
#  'My girlfriend asked me to describe her. How should I do that?\n',
#  'Why do most people I know prefer a BMW so much to a Mercedes Benz or Audi?\n',
#  'How and when do people decide on getting a tattoo?\n',
#  'How do you not go crazy?\n',
#  'What do you think about Greeks?\n',
#  'How do I give up a habit?\n',
#  'Where do you find Malaysian Remy Hair Extensions?\n',
#  'How do I edit a question I asked on Quora?\n',
#  'How do I find a work?\n',
#  'What should I do to love a girl?\n',
#  'How do you know if a friend likes you?\n',
#  'What can you tell about Aun San Suu Kyi as a person?\n',
#  "How do I stop obsessing over a guy I don't know?\n",
#  'How do you write a money order?\n',
#  'What do you do if you like someone?\n',
#  'What happens if you do not finish every question of a Wonderlic pre-assessment?\n',
#  'What should I do to look like a geek?\n',
#  'How do you become a neuropsychiatrist?\n',
#  'How do teachers tell if someone cheated on a test?\n',
#  'How do you do a IMEI check on an iPhone?\n',
#  'What do you think about Orthodox Jews?\n',
#  'How should one start things to ask a girl out?\n',
#  "How do I know if I'm alive or dead as I type this question?\n",
#  'What do you think about Tony Robbins?\n',
#  'How do I get a man to ask me out?\n',
#  'How do you catch a Cheater?\n',
#  'How do I know if a girl wants to kiss me?\n',
#  'When I dream about a person, do I like him?\n',
#  "What do you think Rahul Gandhi would do if he wasn't a Gandhi?\n",
#  'How do I ask a shy girl out?\n',
#  'How do you get a haircut?\n',
#  'What do you not like about Stack Overflow?\n',
#  'What should I do to master something like a technique?\n',
#  "What questions can I answer on Quora when I don't know anything?\n",
#  'How do some people find me on Instagram?\n',
#  'How do you find dy/dx?\n',
#  "Why can't you prove a negative?\n",
#  'How do I take myself seriously?\n',
#  "How do I talk to a boy at school that I don't know?\n",
#  'How do you think about Adrianne Ho?\n',
#  'How do I make people take me seriously?\n',
#  "I'm a girl how do I know if a girl likes me?\n",
#  'What do you think about Israel?\n',
#  'Why do you buy something you do not need?\n',
#  'What do you think about Tinder?\n',
#  'I think I like my teacher. What do I do?\n',
#  'How do I get more people to ask me questions on Quora?\n',
#  'What do you think about Rashtriya Swayamsevak Sangh?\n',
#  'Why do you think about DOTA2?\n',
#  'What do you do if you want to get a law degree?\n',
#  'What can I do if I get a time machine now?\n',
#  'Why do you not like Hillary Clinton?\n',
#  'How do I say no to a friend in need?\n',
#  'How do you get a guy you just met to ask you out?\n',
#  'How do I know a girl is Virgin or not?\n',
#  'How do I know if I have a acting talent or not?\n',
#  'How do you write a complaint?\n',
#  'What do you do if no one cares about you?\n',
#  "What should I do if people don't value me?\n",
#  'How do you get even with a coworker?\n',
#  'How do you get a man?\n',
#  "I'm afraid to tell someone to stop if they're picking on me. What do I do?\n",
#  'What will you do if you feel like a loser?\n',
#  'What do you think about The Venus Project?\n',
#  'What do you tell a girl when she asks "why do you like me?"\n',
#  'What do you think about onecoin?\n',
#  "Why don't I love myself?\n",
#  'Should I get a Dell XPS 13″ or a MacBook Pro Retina 13″? How do they compare to each other?\n',
#  'How do you find a true love?\n',
#  'What should I do if a girl cheated on me?\n',
#  'What should I do when someone answers my question?\n',
#  'What do you think about PETA?\n',
#  "I don't have a laptop/PC. Neither do I have money to buy a laptop. But I want learn coding by myself. What should I do?\n",
#  "I have a girlfriend, and I don't love her anymore. What do I do?\n",
#  'The CTO asks me to give him a reason for everything I do, is this normal?\n',
#  'How did you decide what you wanted to do as a career?\n',
#  "How do I tell my parent I don't believe in God?\n",
#  'How can I explain about LGBT to a kid?\n',
#  'Why do you lie on Quora?\n',
#  'How do you tell a boy you like him?\n',
#  'How do you tell if a boy likes you?\n',
#  "How do I remove my number from Instagram so people who have me as a contact can't find me?\n",
#  'I have a hopeless crush on someone I have no chance with. How do I stop it?\n',
#  'If u like a girl do you ask her out?\n',
#  'How do I ask a question on Quora without making the question vague?\n',
#  'What do you think about Jpegmini.com?\n',
#  'What do you think about Indonesia?\n',
#  "Why don't people on Quora answer to my questions?\n",
#  'How do you add topics upon asking a question on Quora?\n',
#  'What do you do when you wake up from a nightmare?\n',
#  'What should I say to ask a girl out?\n',
#  'How do you fix a Honeywell Thermostat?\n',
#  'Boredom: What do you do on internet when you get bored?\n',
#  'How do you know if you like a guy?\n',
#  'What do you think about Saudi Arabia?\n',
#  'What do you think about Anonymous?\n',
#  "Why don't Eminem or Kanye west smile a lot?\n",
#  'How do i find time for everything?\n',
#  'What do you think about Activecampaing.com?\n',
#  'How do I know if a girl likes me at school?\n',
#  "What can I do when I'm 18?\n",
#  'What do you think about Homeschooling?\n',
#  "Why do people do things that you don't like?\n",
#  "I don't like when boys talk so dirtily in front of me...how do I react at that time? Can I make a change?\n",
#  "What do you do when your parents don't believe in you?\n",
#  'I am confused,what can i do?\n',
#  'How do I find the right one?\n',
#  'How do you find the right person?\n',
#  'How do I know if someone blocked me on Instagram or not?\n',
#  'How do I delete a Snapchat Memory that I have sent?\n',
#  "My teacher is asking me to do his personal work. How do I say no so I don't have to do it at all?\n",
#  'What do you think about Justin Bieber?\n',
#  "Why don't a lot of wise people answer questions on Quora?\n",
#  'How do you ask a question in Quora with anonymity on?\n',
#  'How do you cope with a bad exam?\n',
#  'What do you think about demonetization?\n',
#  'How do I talk to a blunt person on Tinder?\n',
#  'What do you think about this?\n',
#  'What do you think about Sennheiser PXC 550?\n',
#  'How do you know if you have a soul?\n',
#  'Why do you answer questions in Quora?\n',
#  'Why do people like to answer on Quora?\n',
#  'How do you become a Messianic Rabbi?\n',
#  'How do you become a better quizzer?\n',
#  'How do you make a watch?\n',
#  'What do you think about Area 51?\n',
#  'I have a crush on a girl who I barely know. How do I approach her?\n',
#  "What don't you understand about Islam?\n",
#  'How do you choose a dentist?\n',
#  'How do I tell my parents that I have a girlfriend?\n',
#  'What do you think about China?\n',
#  'Why do smart people have to ask questions on Quora?\n',
#  'What do you think about fixiegear.com?\n',
#  "I am a 20-year-old guy. I don't have a girlfriend yet. Am I missing something?\n",
#  'How do you make a girl laugh?\n',
#  'How do I ask for a question on Quora to be clarified?\n',
#  'How do you know if a guy likes a girl?\n',
#  'How do you bisect a right angle?\n',
#  'I am interested in a girl but she wants to just be friends. What do I do?\n',
#  'What do you think about President Rodrigo Duterte?\n',
#  'What should I do if a girl I like is deciding whether to date me or not?\n',
#  'How do I tell if someone is a prostitute?\n',
#  "Why do people ask me to answer questions that there's no reason to think I know the answer for?\n",
#  'How can I forget about a friend?\n',
#  'What do you think about Brazilians?\n',
#  'What do you know about GST?\n',
#  'What do you know about Malaysia?\n',
#  'What do you want to ask about China?\n',
#  'What do I do if I have downvoted some answers by mistake?\n',
#  'Why do you not like Brandon Sanderson?\n',
#  'What questions do you ask clients that need a website?\n',
#  'How do you say someone who you lost a long time ago?\n',
#  'What do you do if you have a tiny penis?\n',
#  'What do you think about India?\n',
#  'What should I do to get a date?\n',
#  'How do you get a girl to like you?\n',
#  'What do you think about Edward Snowden?\n',
#  'How do I take care of a Ginseng Bonsai?\n',
#  'How do I answer my personal most-dreaded question, "how many siblings do you have?"\n',
#  'How can I find a girl who will love me for what I do?\n',
#  'How do I make a person care for me?\n',
#  'Why do friends feel they need me?\n',
#  'I have a major crush on this girl. What do I do?\n',
#  'How do I know if someone is not into me?\n',
#  'Can I write a check to myself? Why or why not?\n',
#  'What shoud I do when I want write a story but I font have any idea?\n',
#  "He doesn't want to talk to me after an argument, what do I do now?\n",
#  'How do I know what I want to ask?\n',
#  'How do you ask a girl to have sex with you? Is it really fun?\n',
#  'How do I find a problem?\n',
#  'How do I fInd a job that I really want?\n',
#  "I'm a girl. Why do female bodies turn me on? Does it make me bi?\n",
#  'what can i do to become fair?\n',
#  "I read a text on her phone and I'm really bothered by it. What do I do?\n",
#  "Why can't you get a date?\n",
#  "I'm a 27-year-old boy without a girlfriend. How do I get one?\n",
#  'What makes you want to answer a question on Quora?\n',
#  "How do I find out who blocked me on Instagram if I don't know them?\n",
#  'How do I get someone to like me?\n',
#  'How do I start a conversation with new people who know me?\n',
#  'Where do you find Gold?\n',
#  'Is there a question that no one on Quora can answer?\n',
#  'Why do Indians complain to me that I am ugly?\n',
#  'How do you watch Hulu on a PS3?\n',
#  'What do you think about Marine Le Pen?\n',
#  'Why do you answer so many questions on Quora?\n',
#  "My mother won't let me do anything on my own. What do I do?\n",
#  'What should I do if I find a dead cat?\n',
#  'How do you find a specific user on MeetMe?\n',
#  "My parents want me to become a doctor but I'm in love with cricket? what can i do to convince them?\n",
#  'In an online lecture, a professor mentioned that Einstein could draw or imagine a 4-dimensional figure. How can one possibly do that?\n',
#  'What do you know about Microsoft Imagine Cup?\n',
#  "Why don't you believe in being a boyfriend?\n",
#  "What do you do when you've nothing to do?\n",
#  "Is there anything Sal Khan can't do?\n",
#  'I like a guy online, what should I do?\n',
#  "Why do I get so angry when things don't go my way?\n",
#  'How do I stop my urge to kill a person?\n',
#  'What do you know about Bangladesh?\n',
#  'What do need to know about a man before you marry him?\n',
#  'If someone asks why do you love me, what should I say?\n',
#  'How do I make a good impression on teacher when I already have a bad one?\n',
#  "How do I open a Master Lock 175 if I don't have the combination?\n",
#  'Where do I get a call girl?\n',
#  'Can you tell me a useless fact?\n',
#  'What can I do with a Chromebook?\n',
#  'What do I do if all my friends hate me?\n',
#  'What do you think about Holberton School?\n',
#  'What do you do if you witness a crime?\n',
#  'How do I know if a friend is attracted to me?\n',
#  'What do you think about Kashmir?\n',
#  'How do i get NBA 2K17 Redeem Code?\n',
#  'What do you think about Japanese?\n',
#  'What do you like about Portugal?\n',
#  'Why do you not use Twitter?\n',
#  'Why do I always feel like a loser?\n',
#  'What can you do with a QR code?\n',
#  'How do you become a Successfull Game Developer?\n',
#  'How do you know if you have a crush on someone?\n',
#  "I badmouthed my gf some time ago. I know it's a terrible thing to do, I regret it so much. I'm scared someone will tell her. What do I do?\n",
#  'How do I know if my friend block me on imo?\n',
#  'What does a Navy SEAL actually do?\n',
#  "I don't find my husband as attractive, like before. How do I change this?\n",
#  'How do I ask a question on Quora? Please help it is very urgent.\n',
#  'Why do I Feel that I need a relationship?\n',
#  "I am a CA Final student and want to leave CA but my parents do not allow me. They don't even want to talk to me on this topic. What should I do?\n",
#  "Why don't some peoples answers have a place to comment?\n",
#  'What do you think about Malala Yousafzai?\n',
#  'How do I know if this girl haves a crush on me?\n',
#  'What do you think about Donald Trump?\n',
#  'How do I ask a girl out at 13?\n',
#  'What do you think about Arnab Goswami?\n',
#  "Why don't people ask more questions on Quora?\n",
#  "How do you respond when someone asks about a scar you don't want to discuss?\n",
#  'How do you know if a contact deleted you on WhatsApp?\n',
#  'What do you know about Bill Gates?\n',
#  'What do you know about Sri Lanka?\n',
#  'What do you think about Jio?\n',
#  'When should you ask a girl out?\n',
#  "What should I do when women don't like me?\n",
#  'What does a start up CEO do?\n',
#  'How do I know if I am a pervert or stalker?\n',
#  'What are some questions you should never ask a Quora user?\n',
#  "How do you ask girls out as an expat if you don't get likes on Tinder/match.com?\n",
#  "Why exactly can't I ask anyone to answer my Quora questions?\n",
#  "Why does Quora tell me that my question needs improving and then link me to a question I didn't ask? Is this a known common bug or am I special?\n",
#  'What do you think about Shawn Mendes?\n',
#  'How do you make a site like Facebook?\n',
#  'How do you ask a girl to have sex with you?\n',
#  'What do guys think when they have a crush?\n',
#  'What do you think about Prentry.com?\n',
#  'How do you take a picture on a MacBook?\n',
#  'Is it hard to ask a question on Quora?\n',
#  'How do I get a husband?\n',
#  'I never ask any question in lecture/meetings. How do I improve this?\n',
#  'How do I know that a guy likes you?\n',
#  'How do you get a business idea?\n',
#  'How do you write a letter to a judge?\n',
#  'I want to be a housewife, what do I do?\n',
#  'How do I know if someone blocked me on WhatsApp or not?\n',
#  'What do you think about Barack Obama?\n',
#  'How do you Get a teacher to like you and do what you want?\n',
#  "Would you like to ask me a question? Go ahead! Don't hold back.\n",
#  'My questions on Quora all need improving. How do you ask a question on Quora?\n',
#  'How do you delete a Kindle book on Kindle?\n',
#  'What do you think about Nicki Minaj?\n',
#  'How do I know when a girl loves me?\n',
#  'Why do some people on Quora do not follow anyone?\n',
#  'How do I tell if I have a cavity?\n',
#  'What do you do if you have no crushes but desperately need a relationship?\n',
#  'What do i say to someone who lost a loved one?\n',
#  'What can I do to tell my story?\n',
#  'How do I know if I have PCOS?\n',
#  'What do you know about IPO?\n',
#  'Why do I think that everyone is fake around me? Why I feel difficult to trust anyone? How do I judge people?\n',
#  "What can I do when I'm alone?\n",
#  "Why don't you like Gary Johnson?\n",
#  "Why do my friends don't want me to have a girlfriend?\n",
#  'What do you think about Arvind Kejriwal?\n',
#  "Why I don't get any answer on my question?\n",
#  'What do you think about MS Dhoni?\n',
#  'What do you do when there simply seems to be no way out in a situation?\n',
#  'How do I find a good roommate?\n',
#  "Why do some people don't like questions?\n",
#  'How do you know that you really like a person?\n',
#  'How do you change a clutch?\n',
#  'How do you know you have a crush on someone?\n',
#  'How do I find a good Muslim girl?\n',
#  'What do you think about minds.com?\n',
#  'What do Xs mean on a datasheet truth table?\n',
#  'What do you think about grammerly.com?\n',
#  'What do you know about Mihai Eminescu?\n',
#  'How do I ask someone to hangout with me if I am depressed and never wanna do anything or be around anyone?\n',
#  'What do you think about Brexit?\n',
#  'How do I have a sex with myself?\n',
#  "I really like a girl and don't know whether she likes me back, what should I do?\n",
#  'I want to become a doctor. How do I go about it?\n',
#  'How do you take off a LifeProof case?\n',
#  'What do you do to get over a bad mood?\n',
#  'What should I do to find a girlfriend?\n',
#  'Why do you choose to be a teacher?\n',
#  'How do I know there is someone for me?\n',
#  'How do I know when I really want to do something?\n',
#  'Has Obama been a bad president? What reasons do you have for thinking so?\n',
#  'Why did Quora remove being able to go "anonymous" when asking a question?\n',
#  'How do you find a good therapist?\n',
#  "I like this girl but I don't know what to do. Any advice?\n",
#  'What do I do, if I like someone and I think they like me back?\n',
#  'What do you think about Leonard Cohen?\n',
#  'How do I ask a girl out for coffee?\n',
#  "How do you make money when you don't have a job?\n",
#  'What do you think about Serbia?\n',
#  'What do you lie about?\n',
#  'I hate myself. What should I do?\n',
#  "Why students don't get a good rank in GATE? What do they do wrong?\n",
#  'I have Body Dysmorphic Disorder and I hate myself; what do I do?\n',
#  'How do I tell if someone is a psychopath?\n',
#  'How do you feel as a Muslim when reading the Bible?\n',
#  'How do you fill up a Zippo?\n',
#  'How do you know if someone likes me?\n',
#  'What do you think about Human Design?\n',
#  'What do you do when you have no friends?\n',
#  'What should I do about facing a girl?\n',
#  'How do you find questions to answer on Stack Overflow?\n',
#  "Why don't people downvote answers on Quora?\n",
#  'How does Nintendo know if a Pokémon is hacked? What do they do to stop it?\n',
#  'How do I know someone blocked me on Facebook?\n',
#  'What do you like to do with you friend? Why?\n',
#  "How can I tell my boss indirectly that I don't want to do the thing he asked me?\n",
#  'How do I find a date on Quora?\n',
#  'How do I post a question here?\n',
#  'How do we forget a fake friend?\n',
#  'If you needed a babysitter what would you do?\n',
#  'What do you think about life?\n',
#  'How do you become a lady-killer?\n',
#  'How do I find my calling?\n',
#  'What do you think about Russian?\n',
#  'How do I know if a girl likes me through text?\n',
#  'How do you know if a girl is trying to end a conversation via text?\n',
#  'How do I know if I actually have a bad memory?\n',
#  'Is it a good idea to quit studying and do what you always wanted to do?\n',
#  'How do I find someone who can help me commercialise a product?\n',
#  'How do I know if I got a panic attack?\n',
#  'How do you know about China?\n',
#  'What can I do if I think I am gay?\n',
#  'How do I get a boyfriend here?\n',
#  'What does it mean to tell a person they have "no class"?\n',
#  'What do you think about DOTA2?\n',
#  'What do you think about vigilantcitizen.com?\n',
#  'Why do you get confused?\n',
#  'Whenever I submit a question for an answer I always find a notification of like this, "This question may need editing". what should I do?\n',
#  "Is there a way to add people you don't know as friends on WhatsApp?\n",
#  'How do you make a friend in  USA ?\n',
#  'How do you backpropagate with a Convolutional Neural Network?\n',
#  'How do you know that a boy likes you?\n',
#  "I want to write a screenplay, but don't know how to start. What do you suggest?\n",
#  "How do I create a Skype link for someone to start a video call with me if I don't have a Skype username?\n",
#  "Why don't the American people give Donald Trump a chance?\n",
#  "I don't want to do a job in EC so what should I do?\n",
#  'How do you know a man?\n',
#  'What do you think about One Direction?\n',
#  'How do I know if this girl likes me?\n',
#  'What question would you have not liked me to ask you?\n',
#  'How do I talk to a girl I have no classes with?\n',
#  'How do I convince this girl to date me?\n',
#  'What would you do if you have a problem saying "no"?\n',
#  'How do I know if I am a psychopath?\n',
#  'What do you think about Reservation System In India?\n',
#  'How do I ask a girl I am about to marry whether she is a virgin or not?\n',
#  'Everything happens for a reason? Why do people believe that to be true?\n',
#  'What do I do if my friend hates me?\n',
#  'What do you think about JKT48?\n',
#  'How do I ask a good question at any conversation or lecture?\n',
#  'Can I ask a question and answer it myself on Quora?\n',
#  "I don't understand, why do people help my friend yet don't help me even though we do the same thing?\n",
#  "What do you do if you don't have a best friend?\n",
#  'How do you make a TV stand?\n',
#  'How do you spot a fake Rolex?\n',
#  "Should I continue doing a job I don't like?\n",
#  'How do you feel to be a teacher?\n',
#  'How do I get a PhD?\n',
#  'What do you think about Russia?\n',
#  ...]
